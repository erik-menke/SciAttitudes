# %%
library(lavaan)
library(readxl)
library(psych)
# Out:
# This is lavaan 0.6-6
# lavaan is BETA software! Please report any bugs.
#
# Attaching package: ‘psych’
#
# The following object is masked from ‘package:lavaan’:
#
#     cor2cov

# %%
path = "/Users/erikmenke/UC-Merced/Data/2018-2019/NSF HSI/2018-2019StudentData/2019Spring/Survey/"
PreSurveyChemDataFilename = "Presurvey.xlsx"
PostSurveyChemDataFilename = "Postsurvey.xlsx"

PreSurveyChemData <- read_excel(paste(path, PreSurveyChemDataFilename, sep=""))
PostSurveyChemData <- read_excel(paste(path, PostSurveyChemDataFilename, sep=""))
# Out:
# New names:
# * Q35 -> Q35...1
# * Q35 -> Q35...96
# New names:
# * Q35 -> Q35...1
# * Q35 -> Q35...96

# %%
describe(PreSurveyChemData[-1,c('Q34_1', 'Q34_2', 'Q34_3', 'Q34_4', 'Q34_5',
                                'Q34_6', 'Q34_7', 'Q34_8', 'Q34_9', 'Q34_10',
                                'Q34_11', 'Q34_12', 'Q34_13', 'Q34_14', 'Q34_15',
                                'Q34_16', 'Q34_17', 'Q34_18', 'Q34_19', 'Q34_20'
                               )])
# Out:
#         vars n   mean     sd       median trimmed  mad    min max range
# Q34_1*   1   690 4.169565 1.681954 4      4.199275 1.4826 1   7   6
# Q34_2*   2   690 5.843478 1.301498 6      6.045290 1.4826 1   7   6
# Q34_3*   3   690 2.946377 1.531013 3      2.813406 1.4826 1   7   6
# Q34_4*   4   690 3.350725 1.459230 3      3.298913 1.4826 1   7   6
# Q34_5*   5   690 3.991304 1.401817 4      3.978261 1.4826 1   7   6
# Q34_6*   6   690 2.495652 1.264961 2      2.396739 1.4826 1   7   6
# Q34_7*   7   690 3.128986 1.451450 3      3.067029 1.4826 1   7   6
# Q34_8*   8   690 4.485507 1.434772 4      4.498188 1.4826 1   7   6
# Q34_9*   9   690 2.927536 1.196498 3      2.894928 1.4826 1   7   6
# Q34_10* 10   690 2.795652 1.243962 3      2.722826 1.4826 1   7   6
# Q34_11* 11   690 3.155072 1.277474 3      3.126812 1.4826 1   7   6
# Q34_12* 12   690 2.433333 1.347703 2      2.275362 1.4826 1   7   6
# Q34_13* 13   690 4.700000 1.251356 4      4.663043 1.4826 1   7   6
# Q34_14* 14   690 3.334783 1.221283 3      3.336957 1.4826 1   7   6
# Q34_15* 15   690 2.452174 1.259462 2      2.355072 1.4826 1   7   6
# Q34_16* 16   690 2.659420 1.372001 3      2.554348 1.4826 1   7   6
# Q34_17* 17   690 4.555072 1.487445 4      4.610507 1.4826 1   7   6
# Q34_18* 18   690 3.040580 1.312474 3      3.047101 1.4826 1   7   6
# Q34_19* 19   690 3.713043 1.361498 4      3.706522 1.4826 1   7   6
# Q34_20* 20   690 4.434783 1.284927 4      4.451087 1.4826 1   7   6
#         skew         kurtosis    se
# Q34_1*  -0.148604997 -0.84302295 0.06403091
# Q34_2*  -1.302495198  1.67294636 0.04954719
# Q34_3*   0.610982208 -0.16872049 0.05828466
# Q34_4*   0.389258185 -0.30868380 0.05555196
# Q34_5*   0.072245911 -0.37354785 0.05336626
# Q34_6*   0.776606987  0.67404847 0.04815624
# Q34_7*   0.278616733 -0.42335706 0.05525574
# Q34_8*  -0.072538023 -0.33115255 0.05462083
# Q34_9*   0.322099124 -0.02065461 0.04554988
# Q34_10*  0.516861954  0.07688994 0.04735682
# Q34_11*  0.242847728  0.06573157 0.04863262
# Q34_12*  0.921245280  0.49414985 0.05130618
# Q34_13*  0.157272546  0.16566785 0.04763832
# Q34_14*  0.038966242  0.23882879 0.04649344
# Q34_15*  0.667132511  0.04871919 0.04794688
# Q34_16*  0.559712356 -0.19260924 0.05223117
# Q34_17* -0.314200079 -0.21297592 0.05662606
# Q34_18* -0.040086095 -0.48055735 0.04996504
# Q34_19* -0.003565077  0.02464421 0.05183133
# Q34_20* -0.150628491  0.66239639 0.04891634

# %%
BioAttPreSubset<-PreSurveyChemData[-1,c('Q34_1', 'Q34_4', 'Q34_5', 'Q34_7', 'Q34_11', 'Q34_14')]
BioAttPreSubset<-na.omit(BioAttPreSubset)
BioAttPreSubset<-as.data.frame(sapply(BioAttPreSubset,as.numeric))

# %%
BioAttPreSubset["Q34_1"]<-(BioAttPreSubset["Q34_1"] - 8)*-1
BioAttPreSubset["Q34_7"]<-(BioAttPreSubset["Q34_7"] - 8)*-1
BioAttPreSubset["Q34_11"]<-(BioAttPreSubset["Q34_11"] - 8)*-1
BioAttPreSubset["Q34_14"]<-(BioAttPreSubset["Q34_14"] - 8)*-1

# %%
describe(BioAttPreSubset)
# Out:
#        vars n   mean     sd       median trimmed  mad    min max range
# Q34_1  1    690 3.830435 1.681954 4      3.800725 1.4826 1   7   6
# Q34_4  2    690 3.350725 1.459230 3      3.298913 1.4826 1   7   6
# Q34_5  3    690 3.991304 1.401817 4      3.978261 1.4826 1   7   6
# Q34_7  4    690 4.871014 1.451450 5      4.932971 1.4826 1   7   6
# Q34_11 5    690 4.844928 1.277474 5      4.873188 1.4826 1   7   6
# Q34_14 6    690 4.665217 1.221283 5      4.663043 1.4826 1   7   6
#        skew        kurtosis    se
# Q34_1   0.14860500 -0.84302295 0.06403091
# Q34_4   0.38925819 -0.30868380 0.05555196
# Q34_5   0.07224591 -0.37354785 0.05336626
# Q34_7  -0.27861673 -0.42335706 0.05525574
# Q34_11 -0.24284773  0.06573157 0.04863262
# Q34_14 -0.03896624  0.23882879 0.04649344

# %%
prebiofit.model<-'Cognition =~ Q34_1 + Q34_4 + Q34_5
                Affect =~ Q34_7 + Q34_11 + Q34_14'

# %%
prebiofit <- cfa(prebiofit.model, data=BioAttPreSubset, estimator="MLR")

# %%
summary(prebiofit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 31 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           690
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 93.674      71.888
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.000       0.000
#   Scaling correction factor                                   1.303
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                              1390.950     890.872
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.561
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.938       0.927
#   Tucker-Lewis Index (TLI)                       0.883       0.863
#
#   Robust Comparative Fit Index (CFI)                         0.939
#   Robust Tucker-Lewis Index (TLI)                            0.886
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -6639.325   -6639.325
#   Scaling correction factor                                  1.400
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -6592.487   -6592.487
#   Scaling correction factor                                  1.363
#       for the MLR correction
#
#   Akaike (AIC)                               13304.649   13304.649
#   Bayesian (BIC)                             13363.626   13363.626
#   Sample-size adjusted Bayesian (BIC)        13322.349   13322.349
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.125       0.108
#   90 Percent confidence interval - lower         0.103       0.088
#   90 Percent confidence interval - upper         0.148       0.128
#   P-value RMSEA <= 0.05                          0.000       0.000
#
#   Robust RMSEA                                               0.123
#   90 Percent confidence interval - lower                     0.098
#   90 Percent confidence interval - upper                     0.150
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.066       0.066
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q34_1             1.000                               1.143    0.680
#     Q34_4             0.865    0.071   12.273    0.000    0.989    0.678
#     Q34_5             1.011    0.090   11.254    0.000    1.155    0.825
#   Affect =~
#     Q34_7             1.000                               1.136    0.784
#     Q34_11            0.863    0.056   15.542    0.000    0.980    0.768
#     Q34_14            0.755    0.057   13.289    0.000    0.858    0.703
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            0.638    0.102    6.278    0.000    0.491    0.491
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q34_1             1.519    0.159    9.574    0.000    1.519    0.538
#    .Q34_4             1.148    0.102   11.218    0.000    1.148    0.540
#    .Q34_5             0.628    0.097    6.498    0.000    0.628    0.320
#    .Q34_7             0.812    0.102    7.955    0.000    0.812    0.386
#    .Q34_11            0.668    0.078    8.532    0.000    0.668    0.410
#    .Q34_14            0.753    0.079    9.479    0.000    0.753    0.506
#     Cognition         1.306    0.170    7.667    0.000    1.000    1.000
#     Affect            1.292    0.129    9.984    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q34_1             0.462
#     Q34_4             0.460
#     Q34_5             0.680
#     Q34_7             0.614
#     Q34_11            0.590
#     Q34_14            0.494

# %%
resid(prebiofit)
# Out:
# $type
# [1] "raw"
#
# $cov
#        Q34_1  Q34_4  Q34_5  Q34_7  Q34_11 Q34_14
# Q34_1   0.000
# Q34_4   0.045  0.000
# Q34_5  -0.071  0.043  0.000
# Q34_7   0.254 -0.283  0.020  0.000
# Q34_11  0.034 -0.345 -0.014  0.028  0.000
# Q34_14  0.304 -0.030  0.109 -0.034 -0.002  0.000

# %%
alpha(BioAttPreSubset[c('Q34_1', 'Q34_4', 'Q34_5')])
# Out:
# Reliability analysis
# Call: alpha(x = BioAttPreSubset[c("Q34_1", "Q34_4", "Q34_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.77      0.77     0.7      0.53 3.4 0.015  3.7 1.3     0.53
#
#  lower alpha upper     95% confidence boundaries
# 0.74 0.77 0.8
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q34_1      0.73      0.73    0.58      0.58 2.8    0.020    NA  0.58
# Q34_4      0.69      0.69    0.53      0.53 2.3    0.023    NA  0.53
# Q34_5      0.64      0.65    0.48      0.48 1.8    0.027    NA  0.48
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q34_1 690  0.83  0.81  0.64   0.57  3.8 1.7
# Q34_4 690  0.82  0.83  0.69   0.60  3.4 1.5
# Q34_5 690  0.83  0.85  0.74   0.64  4.0 1.4
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q34_1 0.08 0.15 0.22 0.17 0.19 0.10 0.07    0
# Q34_4 0.10 0.19 0.29 0.21 0.12 0.06 0.03    0
# Q34_5 0.04 0.10 0.24 0.27 0.22 0.09 0.04    0

# %%
alpha(BioAttPreSubset[c('Q34_7', 'Q34_11', 'Q34_14')])
# Out:
# Reliability analysis
# Call: alpha(x = BioAttPreSubset[c("Q34_7", "Q34_11", "Q34_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.79      0.79    0.72      0.56 3.9 0.014  4.8 1.1     0.54
#
#  lower alpha upper     95% confidence boundaries
# 0.77 0.79 0.82
#
#  Reliability if an item is dropped:
#        raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q34_7       0.70      0.70    0.54      0.54 2.3    0.023    NA  0.54
# Q34_11      0.69      0.69    0.53      0.53 2.3    0.023    NA  0.53
# Q34_14      0.76      0.76    0.62      0.62 3.2    0.018    NA  0.62
#
#  Item statistics
#          n raw.r std.r r.cor r.drop mean  sd
# Q34_7  690  0.87  0.85  0.74   0.66  4.9 1.5
# Q34_11 690  0.85  0.85  0.74   0.66  4.8 1.3
# Q34_14 690  0.81  0.82  0.66   0.59  4.7 1.2
#
# Non missing response frequency for each item
#           1    2    3    4    5    6    7 miss
# Q34_7  0.01 0.05 0.09 0.25 0.26 0.17 0.17    0
# Q34_11 0.01 0.03 0.06 0.31 0.29 0.19 0.11    0
# Q34_14 0.01 0.03 0.07 0.39 0.27 0.15 0.09    0

# %%
BioAttPostSubset<-PostSurveyChemData[-1,c('Q34_1', 'Q34_4', 'Q34_5', 'Q34_7', 'Q34_11', 'Q34_14')]
BioAttPostSubset<-na.omit(BioAttPostSubset)
BioAttPostSubset<-as.data.frame(sapply(BioAttPostSubset,as.numeric))

# %%
BioAttPostSubset["Q34_1"]<-(BioAttPostSubset["Q34_1"] - 8)*-1
BioAttPostSubset["Q34_7"]<-(BioAttPostSubset["Q34_7"] - 8)*-1
BioAttPostSubset["Q34_11"]<-(BioAttPostSubset["Q34_11"] - 8)*-1
BioAttPostSubset["Q34_14"]<-(BioAttPostSubset["Q34_14"] - 8)*-1

# %%
postbiofit.model<-'Cognition =~ Q34_1 + Q34_4 + Q34_5
                Affect =~ Q34_7 + Q34_11 + Q34_14'

# %%
postbiofit <- cfa(postbiofit.model, data=BioAttPostSubset, estimator="MLR")

# %%
summary(postbiofit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 32 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           178
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 45.996      38.056
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.000       0.000
#   Scaling correction factor                                   1.209
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                               545.342     394.043
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.384
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.928       0.921
#   Tucker-Lewis Index (TLI)                       0.866       0.851
#
#   Robust Comparative Fit Index (CFI)                         0.931
#   Robust Tucker-Lewis Index (TLI)                            0.870
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -1714.364   -1714.364
#   Scaling correction factor                                  1.253
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -1691.366   -1691.366
#   Scaling correction factor                                  1.236
#       for the MLR correction
#
#   Akaike (AIC)                                3454.728    3454.728
#   Bayesian (BIC)                              3496.091    3496.091
#   Sample-size adjusted Bayesian (BIC)         3454.921    3454.921
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.163       0.145
#   90 Percent confidence interval - lower         0.119       0.105
#   90 Percent confidence interval - upper         0.211       0.189
#   P-value RMSEA <= 0.05                          0.000       0.000
#
#   Robust RMSEA                                               0.160
#   90 Percent confidence interval - lower                     0.111
#   90 Percent confidence interval - upper                     0.212
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.085       0.085
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q34_1             1.000                               1.206    0.689
#     Q34_4             0.874    0.137    6.392    0.000    1.055    0.674
#     Q34_5             1.066    0.172    6.190    0.000    1.285    0.848
#   Affect =~
#     Q34_7             1.000                               1.380    0.828
#     Q34_11            0.917    0.056   16.483    0.000    1.266    0.890
#     Q34_14            0.760    0.066   11.512    0.000    1.048    0.830
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            0.960    0.267    3.599    0.000    0.577    0.577
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q34_1             1.611    0.295    5.456    0.000    1.611    0.525
#    .Q34_4             1.338    0.241    5.558    0.000    1.338    0.546
#    .Q34_5             0.645    0.234    2.757    0.006    0.645    0.281
#    .Q34_7             0.870    0.144    6.045    0.000    0.870    0.314
#    .Q34_11            0.420    0.103    4.094    0.000    0.420    0.208
#    .Q34_14            0.496    0.097    5.118    0.000    0.496    0.311
#     Cognition         1.455    0.351    4.140    0.000    1.000    1.000
#     Affect            1.905    0.247    7.722    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q34_1             0.475
#     Q34_4             0.454
#     Q34_5             0.719
#     Q34_7             0.686
#     Q34_11            0.792
#     Q34_14            0.689

# %%
describe(BioAttPostSubset)
# Out:
#        vars n   mean     sd       median trimmed  mad    min max range
# Q34_1  1    178 3.696629 1.755730 4      3.631944 1.4826 1   7   6
# Q34_4  2    178 3.196629 1.569695 3      3.090278 1.4826 1   7   6
# Q34_5  3    178 3.707865 1.519755 4      3.645833 1.4826 1   7   6
# Q34_7  4    178 4.449438 1.670693 4      4.493056 1.4826 1   7   6
# Q34_11 5    178 4.612360 1.426649 4      4.645833 1.4826 1   7   6
# Q34_14 6    178 4.556180 1.266559 4      4.583333 1.4826 1   7   6
#        skew       kurtosis    se
# Q34_1   0.2714881 -0.82160283 0.13159752
# Q34_4   0.4857158 -0.36215487 0.11765364
# Q34_5   0.3052496 -0.54383375 0.11391045
# Q34_7  -0.1834656 -0.77199385 0.12522372
# Q34_11 -0.2547819  0.08932892 0.10693184
# Q34_14 -0.2582185  0.62122151 0.09493258

# %%
alpha(BioAttPostSubset[c('Q34_1', 'Q34_4', 'Q34_5')])
# Out:
# Reliability analysis
# Call: alpha(x = BioAttPostSubset[c("Q34_1", "Q34_4", "Q34_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.78      0.78    0.71      0.54 3.6 0.029  3.5 1.3     0.54
#
#  lower alpha upper     95% confidence boundaries
# 0.72 0.78 0.83
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q34_1      0.76      0.76    0.61      0.61 3.1    0.036    NA  0.61
# Q34_4      0.70      0.70    0.54      0.54 2.4    0.045    NA  0.54
# Q34_5      0.64      0.65    0.48      0.48 1.8    0.053    NA  0.48
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q34_1 178  0.82  0.81  0.64   0.57  3.7 1.8
# Q34_4 178  0.83  0.84  0.71   0.62  3.2 1.6
# Q34_5 178  0.85  0.86  0.76   0.67  3.7 1.5
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q34_1 0.11 0.16 0.22 0.19 0.15 0.08 0.09    0
# Q34_4 0.15 0.24 0.19 0.25 0.10 0.04 0.04    0
# Q34_5 0.06 0.17 0.26 0.21 0.17 0.08 0.05    0

# %%
alpha(BioAttPostSubset[c('Q34_7', 'Q34_11', 'Q34_14')])
# Out:
# Reliability analysis
# Call: alpha(x = BioAttPostSubset[c("Q34_7", "Q34_11", "Q34_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.88      0.88    0.84      0.72 7.7 0.015  4.5 1.3     0.74
#
#  lower alpha upper     95% confidence boundaries
# 0.85 0.88 0.91
#
#  Reliability if an item is dropped:
#        raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q34_7       0.85      0.85    0.74      0.74 5.7    0.023    NA  0.74
# Q34_11      0.78      0.80    0.67      0.67 4.0    0.030    NA  0.67
# Q34_14      0.85      0.86    0.75      0.75 6.0    0.022    NA  0.75
#
#  Item statistics
#          n raw.r std.r r.cor r.drop mean  sd
# Q34_7  178  0.91  0.89  0.81   0.76  4.4 1.7
# Q34_11 178  0.92  0.92  0.87   0.81  4.6 1.4
# Q34_14 178  0.87  0.89  0.80   0.75  4.6 1.3
#
# Non missing response frequency for each item
#           1    2    3    4    5    6    7 miss
# Q34_7  0.04 0.11 0.10 0.29 0.16 0.17 0.13    0
# Q34_11 0.04 0.02 0.10 0.35 0.24 0.14 0.12    0
# Q34_14 0.03 0.03 0.06 0.41 0.26 0.14 0.07    0
