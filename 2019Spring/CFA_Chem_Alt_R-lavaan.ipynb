# %%
library(lavaan)
library(readxl)
library(psych)
# Out:
# This is lavaan 0.6-6
# lavaan is BETA software! Please report any bugs.
#
# Attaching package: ‘psych’
#
# The following object is masked from ‘package:lavaan’:
#
#     cor2cov

# %%
path = "/Users/erikmenke/UC-Merced/Data/2018-2019/NSF HSI/2018-2019StudentData/2019Spring/Survey/"
PreSurveyChemDataFilename = "Presurvey.xlsx"
PostSurveyChemDataFilename = "Postsurvey.xlsx"

PreSurveyChemData <- read_excel(paste(path, PreSurveyChemDataFilename, sep=""))
PostSurveyChemData <- read_excel(paste(path, PostSurveyChemDataFilename, sep=""))
# Out:
# New names:
# * Q35 -> Q35...1
# * Q35 -> Q35...96
# New names:
# * Q35 -> Q35...1
# * Q35 -> Q35...96

# %%
describe(PreSurveyChemData[-1,c('Q1_1', 'Q1_2', 'Q1_3', 'Q1_4', 'Q1_5',
                                'Q1_6', 'Q1_7', 'Q1_8', 'Q1_9', 'Q1_10',
                                'Q1_11', 'Q1_12', 'Q1_13', 'Q1_14', 'Q1_15',
                                'Q1_16', 'Q1_17', 'Q1_18', 'Q1_19', 'Q1_20'
                               )])
# Out:
#        vars n   mean     sd       median trimmed  mad    min max range
# Q1_1*   1   699 4.432046 1.394587 4      4.467023 1.4826 1   7   6
# Q1_2*   2   699 5.761087 1.132422 6      5.871658 1.4826 1   7   6
# Q1_3*   3   699 3.427754 1.448792 3      3.402852 1.4826 1   7   6
# Q1_4*   4   699 3.110157 1.232626 3      3.083779 1.4826 1   7   6
# Q1_5*   5   699 3.666667 1.266345 4      3.631016 1.4826 1   7   6
# Q1_6*   6   699 2.673820 1.260845 3      2.618538 1.4826 1   7   6
# Q1_7*   7   699 3.610873 1.548711 4      3.591800 1.4826 1   7   6
# Q1_8*   8   699 4.208870 1.407870 4      4.237077 1.4826 1   7   6
# Q1_9*   9   699 3.084406 1.198148 3      3.035651 1.4826 1   7   6
# Q1_10* 10   699 2.547926 1.105563 2      2.488414 1.4826 1   7   6
# Q1_11* 11   699 3.555079 1.235013 4      3.532977 1.4826 1   7   6
# Q1_12* 12   699 2.728183 1.314649 3      2.618538 1.4826 1   7   6
# Q1_13* 13   699 4.537911 1.145407 4      4.516934 1.4826 1   7   6
# Q1_14* 14   699 3.619456 1.275050 4      3.618538 1.4826 1   7   6
# Q1_15* 15   699 2.586552 1.197845 3      2.532977 1.4826 1   7   6
# Q1_16* 16   699 2.493562 1.281744 2      2.395722 1.4826 1   7   6
# Q1_17* 17   699 4.583691 1.459017 5      4.639929 1.4826 1   7   6
# Q1_18* 18   699 3.662375 1.333028 4      3.689840 1.4826 1   7   6
# Q1_19* 19   699 3.360515 1.200018 3      3.356506 1.4826 1   7   6
# Q1_20* 20   699 4.290415 1.242770 4      4.327986 1.4826 1   7   6
#        skew        kurtosis    se
# Q1_1*  -0.20987841 -0.18346304 0.05274814
# Q1_2*  -0.69345334  0.07043017 0.04283215
# Q1_3*   0.19578874 -0.40715733 0.05479836
# Q1_4*   0.27163358 -0.16972601 0.04662219
# Q1_5*   0.18613847 -0.27495937 0.04789756
# Q1_6*   0.46255633  0.01906682 0.04768952
# Q1_7*   0.13000858 -0.61555681 0.05857764
# Q1_8*  -0.18829559 -0.04993600 0.05325055
# Q1_9*   0.44652288  0.30913804 0.04531812
# Q1_10*  0.57131115  0.30612509 0.04181624
# Q1_11*  0.20626563  0.37141884 0.04671248
# Q1_12*  0.64838020  0.35787918 0.04972459
# Q1_13*  0.10418437  0.81185712 0.04332325
# Q1_14*  0.06212353  0.14389859 0.04822682
# Q1_15*  0.49994474  0.15114039 0.04530667
# Q1_16*  0.68280223  0.23293432 0.04848000
# Q1_17* -0.34493099 -0.29696746 0.05518509
# Q1_18* -0.16476391 -0.03230641 0.05041975
# Q1_19*  0.06633850  0.04152616 0.04538885
# Q1_20* -0.26635416  0.58019025 0.04700589

# %%
ChemAttPreSubset<-PreSurveyChemData[-1,c('Q1_1', 'Q1_4', 'Q1_5', 'Q1_7', 'Q1_11', 'Q1_14')]
ChemAttPreSubset<-na.omit(ChemAttPreSubset)
ChemAttPreSubset<-as.data.frame(sapply(ChemAttPreSubset,as.numeric))

# %%
ChemAttPreSubset["Q1_1"]<-(ChemAttPreSubset["Q1_1"] - 8)*-1
ChemAttPreSubset["Q1_7"]<-(ChemAttPreSubset["Q1_7"] - 8)*-1
ChemAttPreSubset["Q1_11"]<-(ChemAttPreSubset["Q1_11"] - 8)*-1
ChemAttPreSubset["Q1_14"]<-(ChemAttPreSubset["Q1_14"] - 8)*-1

# %%
describe(ChemAttPreSubset)
# Out:
#       vars n   mean     sd       median trimmed  mad    min max range
# Q1_1  1    699 3.567954 1.394587 4      3.532977 1.4826 1   7   6
# Q1_4  2    699 3.110157 1.232626 3      3.083779 1.4826 1   7   6
# Q1_5  3    699 3.666667 1.266345 4      3.631016 1.4826 1   7   6
# Q1_7  4    699 4.389127 1.548711 4      4.408200 1.4826 1   7   6
# Q1_11 5    699 4.444921 1.235013 4      4.467023 1.4826 1   7   6
# Q1_14 6    699 4.380544 1.275050 4      4.381462 1.4826 1   7   6
#       skew        kurtosis   se
# Q1_1   0.20987841 -0.1834630 0.05274814
# Q1_4   0.27163358 -0.1697260 0.04662219
# Q1_5   0.18613847 -0.2749594 0.04789756
# Q1_7  -0.13000858 -0.6155568 0.05857764
# Q1_11 -0.20626563  0.3714188 0.04671248
# Q1_14 -0.06212353  0.1438986 0.04822682

# %%
prechemfit.model<-'Cognition =~ Q1_1 + Q1_4 + Q1_5
                Affect =~ Q1_7 + Q1_11 + Q1_14'

#prechemfit.model<-'Cognition =~ Q1_1 + Q1_4 + Q1_5 + Q1_7 + Q1_11 + Q1_14'

# %%
prechemfit <- cfa(prechemfit.model, data=ChemAttPreSubset, estimator="MLR")

# %%
summary(prechemfit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 29 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           699
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 60.470      49.514
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.000       0.000
#   Scaling correction factor                                   1.221
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                              1555.502    1154.340
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.348
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.966       0.964
#   Tucker-Lewis Index (TLI)                       0.936       0.932
#
#   Robust Comparative Fit Index (CFI)                         0.967
#   Robust Tucker-Lewis Index (TLI)                            0.938
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -6367.400   -6367.400
#   Scaling correction factor                                  1.239
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -6337.165   -6337.165
#   Scaling correction factor                                  1.232
#       for the MLR correction
#
#   Akaike (AIC)                               12760.799   12760.799
#   Bayesian (BIC)                             12819.945   12819.945
#   Sample-size adjusted Bayesian (BIC)        12778.667   12778.667
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.097       0.086
#   90 Percent confidence interval - lower         0.075       0.066
#   90 Percent confidence interval - upper         0.120       0.108
#   P-value RMSEA <= 0.05                          0.000       0.002
#
#   Robust RMSEA                                               0.095
#   90 Percent confidence interval - lower                     0.071
#   90 Percent confidence interval - upper                     0.121
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.046       0.046
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q1_1              1.000                               0.962    0.690
#     Q1_4              0.872    0.071   12.205    0.000    0.838    0.681
#     Q1_5              1.105    0.079   14.052    0.000    1.063    0.840
#   Affect =~
#     Q1_7              1.000                               1.186    0.766
#     Q1_11             0.799    0.048   16.670    0.000    0.947    0.768
#     Q1_14             0.787    0.051   15.316    0.000    0.933    0.732
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            0.779    0.092    8.468    0.000    0.683    0.683
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q1_1              1.017    0.088   11.543    0.000    1.017    0.524
#    .Q1_4              0.814    0.070   11.564    0.000    0.814    0.537
#    .Q1_5              0.471    0.060    7.917    0.000    0.471    0.294
#    .Q1_7              0.989    0.092   10.727    0.000    0.989    0.413
#    .Q1_11             0.625    0.063    9.994    0.000    0.625    0.411
#    .Q1_14             0.753    0.070   10.696    0.000    0.753    0.464
#     Cognition         0.925    0.114    8.124    0.000    1.000    1.000
#     Affect            1.406    0.127   11.060    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q1_1              0.476
#     Q1_4              0.463
#     Q1_5              0.706
#     Q1_7              0.587
#     Q1_11             0.589
#     Q1_14             0.536

# %%
resid(prechemfit)
# Out:
# $type
# [1] "raw"
#
# $cov
#       Q1_1   Q1_4   Q1_5   Q1_7   Q1_11  Q1_14
# Q1_1   0.000
# Q1_4  -0.032  0.000
# Q1_5  -0.036  0.047  0.000
# Q1_7   0.163 -0.077  0.008  0.000
# Q1_11  0.056 -0.164 -0.109  0.051  0.000
# Q1_14  0.199 -0.003  0.074 -0.078  0.013  0.000

# %%
alpha(ChemAttPreSubset[c('Q1_1', 'Q1_4', 'Q1_5')])
# Out:
# Reliability analysis
# Call: alpha(x = ChemAttPreSubset[c("Q1_1", "Q1_4", "Q1_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.77      0.78    0.71      0.54 3.5 0.015  3.4 1.1     0.56
#
#  lower alpha upper     95% confidence boundaries
# 0.74 0.77 0.8
#
#  Reliability if an item is dropped:
#      raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q1_1      0.75      0.75    0.60      0.60 3.0    0.019    NA  0.60
# Q1_4      0.72      0.72    0.56      0.56 2.5    0.021    NA  0.56
# Q1_5      0.62      0.62    0.45      0.45 1.6    0.029    NA  0.45
#
#  Item statistics
#        n raw.r std.r r.cor r.drop mean  sd
# Q1_1 699  0.82  0.81  0.64   0.57  3.6 1.4
# Q1_4 699  0.81  0.82  0.68   0.59  3.1 1.2
# Q1_5 699  0.86  0.87  0.78   0.68  3.7 1.3
#
# Non missing response frequency for each item
#         1    2    3    4    5    6    7 miss
# Q1_1 0.08 0.13 0.29 0.28 0.13 0.07 0.03    0
# Q1_4 0.10 0.20 0.34 0.24 0.08 0.04 0.00    0
# Q1_5 0.03 0.15 0.28 0.30 0.17 0.06 0.01    0

# %%
alpha(ChemAttPreSubset[c('Q1_7', 'Q1_11', 'Q1_14')])
# Out:
# Reliability analysis
# Call: alpha(x = ChemAttPreSubset[c("Q1_7", "Q1_11", "Q1_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.79       0.8    0.73      0.57   4 0.013  4.4 1.1     0.57
#
#  lower alpha upper     95% confidence boundaries
# 0.77 0.79 0.82
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q1_7       0.73      0.73    0.57      0.57 2.7    0.021    NA  0.57
# Q1_11      0.68      0.69    0.52      0.52 2.2    0.024    NA  0.52
# Q1_14      0.75      0.76    0.61      0.61 3.2    0.018    NA  0.61
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q1_7  699  0.87  0.84  0.72   0.64  4.4 1.5
# Q1_11 699  0.85  0.86  0.76   0.68  4.4 1.2
# Q1_14 699  0.81  0.83  0.68   0.60  4.4 1.3
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q1_7  0.04 0.08 0.17 0.25 0.21 0.16 0.10    0
# Q1_11 0.02 0.04 0.11 0.37 0.28 0.13 0.05    0
# Q1_14 0.02 0.05 0.14 0.36 0.26 0.11 0.06    0

# %%
ChemAttPostSubset<-PostSurveyChemData[-1,c('Q1_1', 'Q1_4', 'Q1_5', 'Q1_7', 'Q1_11', 'Q1_14')]
ChemAttPostSubset<-na.omit(ChemAttPostSubset)
ChemAttPostSubset<-as.data.frame(sapply(ChemAttPostSubset,as.numeric))

# %%
ChemAttPostSubset["Q1_1"]<-(ChemAttPostSubset["Q1_1"] - 8)*-1
ChemAttPostSubset["Q1_7"]<-(ChemAttPostSubset["Q1_7"] - 8)*-1
ChemAttPostSubset["Q1_11"]<-(ChemAttPostSubset["Q1_11"] - 8)*-1
ChemAttPostSubset["Q1_14"]<-(ChemAttPostSubset["Q1_14"] - 8)*-1

# %%
postchemfit.model<-'Cognition =~ Q1_1 + Q1_4 + Q1_5
                Affect =~ Q1_7 + Q1_11 + Q1_14'

# %%
postchemfit <- cfa(postchemfit.model, data=ChemAttPostSubset, estimator="MLR")

# %%
summary(postchemfit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 31 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           190
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 33.936      30.688
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.000       0.000
#   Scaling correction factor                                   1.106
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                               580.817     467.903
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.241
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.954       0.950
#   Tucker-Lewis Index (TLI)                       0.914       0.906
#
#   Robust Comparative Fit Index (CFI)                         0.955
#   Robust Tucker-Lewis Index (TLI)                            0.916
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -1724.916   -1724.916
#   Scaling correction factor                                  1.155
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -1707.947   -1707.947
#   Scaling correction factor                                  1.136
#       for the MLR correction
#
#   Akaike (AIC)                                3475.831    3475.831
#   Bayesian (BIC)                              3518.042    3518.042
#   Sample-size adjusted Bayesian (BIC)         3476.864    3476.864
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.131       0.122
#   90 Percent confidence interval - lower         0.087       0.080
#   90 Percent confidence interval - upper         0.177       0.167
#   P-value RMSEA <= 0.05                          0.002       0.004
#
#   Robust RMSEA                                               0.128
#   90 Percent confidence interval - lower                     0.082
#   90 Percent confidence interval - upper                     0.178
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.054       0.054
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q1_1              1.000                               1.069    0.710
#     Q1_4              0.830    0.115    7.217    0.000    0.887    0.735
#     Q1_5              1.119    0.139    8.058    0.000    1.196    0.900
#   Affect =~
#     Q1_7              1.000                               1.309    0.774
#     Q1_11             0.946    0.064   14.853    0.000    1.239    0.878
#     Q1_14             0.766    0.078    9.877    0.000    1.003    0.779
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            0.953    0.190    5.005    0.000    0.681    0.681
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q1_1              1.125    0.187    6.025    0.000    1.125    0.496
#    .Q1_4              0.671    0.101    6.674    0.000    0.671    0.460
#    .Q1_5              0.334    0.104    3.209    0.001    0.334    0.189
#    .Q1_7              1.145    0.169    6.773    0.000    1.145    0.400
#    .Q1_11             0.455    0.111    4.112    0.000    0.455    0.229
#    .Q1_14             0.652    0.116    5.627    0.000    0.652    0.393
#     Cognition         1.142    0.236    4.833    0.000    1.000    1.000
#     Affect            1.715    0.235    7.305    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q1_1              0.504
#     Q1_4              0.540
#     Q1_5              0.811
#     Q1_7              0.600
#     Q1_11             0.771
#     Q1_14             0.607

# %%
describe(ChemAttPostSubset)
# Out:
#       vars n   mean     sd       median trimmed  mad    min max range
# Q1_1  1    190 3.378947 1.509609 3      3.315789 1.4826 1   7   6
# Q1_4  2    190 2.973684 1.210336 3      2.934211 1.4826 1   7   6
# Q1_5  3    190 3.521053 1.332174 3      3.526316 1.4826 1   7   6
# Q1_7  4    190 4.321053 1.695646 4      4.361842 1.4826 1   7   6
# Q1_11 5    190 4.300000 1.414026 4      4.394737 1.4826 1   7   6
# Q1_14 6    190 4.063158 1.291490 4      4.125000 1.4826 1   7   6
#       skew        kurtosis   se
# Q1_1   0.35493598 -0.4266249 0.10951855
# Q1_4   0.37064445 -0.1133311 0.08780697
# Q1_5   0.03520526 -0.5373781 0.09664604
# Q1_7  -0.24687333 -0.8668277 0.12301510
# Q1_11 -0.44721781  0.1565159 0.10258426
# Q1_14 -0.35128942  0.1040635 0.09369457

# %%
alpha(ChemAttPostSubset[c('Q1_1', 'Q1_4', 'Q1_5')])
# Out:
# Reliability analysis
# Call: alpha(x = ChemAttPostSubset[c("Q1_1", "Q1_4", "Q1_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.81      0.82    0.76       0.6 4.6 0.023  3.3 1.2     0.62
#
#  lower alpha upper     95% confidence boundaries
# 0.77 0.81 0.86
#
#  Reliability if an item is dropped:
#      raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q1_1      0.81      0.81    0.68      0.68 4.2    0.028    NA  0.68
# Q1_4      0.77      0.77    0.62      0.62 3.3    0.034    NA  0.62
# Q1_5      0.66      0.67    0.51      0.51 2.1    0.047    NA  0.51
#
#  Item statistics
#        n raw.r std.r r.cor r.drop mean  sd
# Q1_1 190  0.85  0.83  0.68   0.62  3.4 1.5
# Q1_4 190  0.83  0.85  0.74   0.65  3.0 1.2
# Q1_5 190  0.89  0.89  0.83   0.74  3.5 1.3
#
# Non missing response frequency for each item
#         1    2    3    4    5    6    7 miss
# Q1_1 0.12 0.16 0.31 0.19 0.12 0.08 0.03    0
# Q1_4 0.11 0.26 0.32 0.21 0.08 0.02 0.01    0
# Q1_5 0.07 0.14 0.31 0.24 0.18 0.06 0.01    0

# %%
alpha(ChemAttPostSubset[c('Q1_7', 'Q1_11', 'Q1_14')])
# Out:
# Reliability analysis
# Call: alpha(x = ChemAttPostSubset[c("Q1_7", "Q1_11", "Q1_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N  ase mean  sd median_r
#       0.84      0.85     0.8      0.65 5.5 0.02  4.2 1.3     0.69
#
#  lower alpha upper     95% confidence boundaries
# 0.8 0.84 0.88
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q1_7       0.82      0.82    0.69      0.69 4.5    0.027    NA  0.69
# Q1_11      0.68      0.70    0.54      0.54 2.3    0.044    NA  0.54
# Q1_14      0.82      0.83    0.71      0.71 4.8    0.025    NA  0.71
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q1_7  190  0.88  0.86  0.75   0.68  4.3 1.7
# Q1_11 190  0.91  0.92  0.87   0.80  4.3 1.4
# Q1_14 190  0.83  0.85  0.73   0.66  4.1 1.3
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q1_7  0.06 0.11 0.15 0.18 0.21 0.19 0.09    0
# Q1_11 0.06 0.04 0.12 0.34 0.25 0.14 0.05    0
# Q1_14 0.05 0.05 0.18 0.36 0.23 0.11 0.02    0
