# %%
library(lavaan)
library(readxl)
library(psych)
# Out:
# This is lavaan 0.6-6
# lavaan is BETA software! Please report any bugs.
#
# Attaching package: ‘psych’
#
# The following object is masked from ‘package:lavaan’:
#
#     cor2cov

# %%
path = "/Users/erikmenke/UC-Merced/Data/2019-2020/NSF HSI/Fall 2019/Survey/Postterm/"
PreSurveyChemDataFilename = "Chem Attitudes_Pre-Fall 2019.xlsx"
PostSurveyChemDataFilename = "Chem Attitudes_Post-Fall 2019.xlsx"

PreSurveyChemData <- read_excel(paste(path, PreSurveyChemDataFilename, sep=""))
PostSurveyChemData <- read_excel(paste(path, PostSurveyChemDataFilename, sep=""))
# Out:
# New names:
# * Q35 -> Q35...1
# * Q35 -> Q35...96
# New names:
# * Q35 -> Q35...1
# * Q35 -> Q35...96

# %%
describe(PreSurveyChemData[-1,c('Q34_1', 'Q34_2', 'Q34_3', 'Q34_4', 'Q34_5',
                                'Q34_6', 'Q34_7', 'Q34_8', 'Q34_9', 'Q34_10',
                                'Q34_11', 'Q34_12', 'Q34_13', 'Q34_14', 'Q34_15',
                                'Q34_16', 'Q34_17', 'Q34_18', 'Q34_19', 'Q34_20'
                               )])
# Out:
#         vars n   mean     sd       median trimmed  mad    min max range
# Q34_1*   1   394 4.093909 1.692316 4      4.091772 1.4826 1   7   6
# Q34_2*   2   394 6.005076 1.249926 6      6.224684 1.4826 1   7   6
# Q34_3*   3   394 2.928934 1.598353 3      2.778481 1.4826 1   7   6
# Q34_4*   4   394 3.210660 1.504459 3      3.132911 1.4826 1   7   6
# Q34_5*   5   394 3.855330 1.513933 4      3.844937 1.4826 1   7   6
# Q34_6*   6   394 2.456853 1.309358 2      2.341772 1.4826 1   7   6
# Q34_7*   7   394 3.035533 1.487439 3      2.943038 1.4826 1   7   6
# Q34_8*   8   394 4.586294 1.424581 4      4.588608 1.4826 1   7   6
# Q34_9*   9   394 2.939086 1.276663 3      2.867089 1.4826 1   7   6
# Q34_10* 10   394 2.758883 1.309676 3      2.642405 1.4826 1   7   6
# Q34_11* 11   394 3.129442 1.315786 3      3.098101 1.4826 1   7   6
# Q34_12* 12   394 2.388325 1.368108 2      2.218354 1.4826 1   7   6
# Q34_13* 13   394 4.791878 1.198954 5      4.740506 1.4826 1   7   6
# Q34_14* 14   394 3.324873 1.208974 3      3.303797 1.4826 1   7   6
# Q34_15* 15   394 2.360406 1.248737 2      2.250000 1.4826 1   7   6
# Q34_16* 16   394 2.642132 1.350281 3      2.531646 1.4826 1   7   6
# Q34_17* 17   394 4.469543 1.474235 4      4.496835 1.4826 1   7   6
# Q34_18* 18   394 3.076142 1.297596 3      3.101266 1.4826 1   7   6
# Q34_19* 19   394 3.723350 1.276969 4      3.734177 1.4826 1   7   6
# Q34_20* 20   394 4.395939 1.193956 4      4.386076 0.7413 1   7   6
#         skew          kurtosis    se
# Q34_1*  -0.0305908111 -0.86876706 0.08525763
# Q34_2*  -1.5692208112  2.92960392 0.06297036
# Q34_3*   0.6527623829 -0.25526519 0.08052388
# Q34_4*   0.4227357296 -0.41412193 0.07579356
# Q34_5*   0.1046916183 -0.60431076 0.07627086
# Q34_6*   0.7179576787  0.21805453 0.06596451
# Q34_7*   0.3927851713 -0.26283535 0.07493609
# Q34_8*  -0.1029153562 -0.36219129 0.07176934
# Q34_9*   0.5088136841  0.21920080 0.06431734
# Q34_10*  0.7277544682  0.36596573 0.06598053
# Q34_11*  0.1692741622 -0.11437829 0.06628836
# Q34_12*  1.0753935380  1.15208417 0.06892431
# Q34_13*  0.2006868460 -0.01298517 0.06040244
# Q34_14*  0.1790427259  0.33827519 0.06090725
# Q34_15*  0.7363916394  0.29559259 0.06291047
# Q34_16*  0.5673635776 -0.20428051 0.06802617
# Q34_17* -0.1972007476 -0.24914645 0.07427091
# Q34_18* -0.0921526684 -0.39559246 0.06537194
# Q34_19* -0.0448412250  0.20497310 0.06433276
# Q34_20*  0.0001330251  0.92826936 0.06015063

# %%
BioAttPreSubset<-PreSurveyChemData[-1,c('Q34_1', 'Q34_4', 'Q34_5', 'Q34_7', 'Q34_11', 'Q34_14')]
BioAttPreSubset<-na.omit(BioAttPreSubset)
BioAttPreSubset<-as.data.frame(sapply(BioAttPreSubset,as.numeric))

# %%
BioAttPreSubset["Q34_1"]<-(BioAttPreSubset["Q34_1"] - 8)*-1
BioAttPreSubset["Q34_7"]<-(BioAttPreSubset["Q34_7"] - 8)*-1
BioAttPreSubset["Q34_11"]<-(BioAttPreSubset["Q34_11"] - 8)*-1
BioAttPreSubset["Q34_14"]<-(BioAttPreSubset["Q34_14"] - 8)*-1

# %%
describe(BioAttPreSubset)
# Out:
#        vars n   mean     sd       median trimmed  mad    min max range
# Q34_1  1    394 3.906091 1.692316 4      3.908228 1.4826 1   7   6
# Q34_4  2    394 3.210660 1.504459 3      3.132911 1.4826 1   7   6
# Q34_5  3    394 3.855330 1.513933 4      3.844937 1.4826 1   7   6
# Q34_7  4    394 4.964467 1.487439 5      5.056962 1.4826 1   7   6
# Q34_11 5    394 4.870558 1.315786 5      4.901899 1.4826 1   7   6
# Q34_14 6    394 4.675127 1.208974 5      4.696203 1.4826 1   7   6
#        skew        kurtosis   se
# Q34_1   0.03059081 -0.8687671 0.08525763
# Q34_4   0.42273573 -0.4141219 0.07579356
# Q34_5   0.10469162 -0.6043108 0.07627086
# Q34_7  -0.39278517 -0.2628353 0.07493609
# Q34_11 -0.16927416 -0.1143783 0.06628836
# Q34_14 -0.17904273  0.3382752 0.06090725

# %%
prebiofit.model<-'Cognition =~ Q34_1 + Q34_4 + Q34_5
                Affect =~ Q34_7 + Q34_11 + Q34_14'

# %%
prebiofit <- cfa(prebiofit.model, data=BioAttPreSubset, estimator="MLR")

# %%
summary(prebiofit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 33 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           394
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 58.258      50.805
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.000       0.000
#   Scaling correction factor                                   1.147
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                               911.210     651.243
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.399
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.944       0.933
#   Tucker-Lewis Index (TLI)                       0.895       0.874
#
#   Robust Comparative Fit Index (CFI)                         0.945
#   Robust Tucker-Lewis Index (TLI)                            0.897
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -3795.830   -3795.830
#   Scaling correction factor                                  1.299
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -3766.701   -3766.701
#   Scaling correction factor                                  1.241
#       for the MLR correction
#
#   Akaike (AIC)                                7617.660    7617.660
#   Bayesian (BIC)                              7669.352    7669.352
#   Sample-size adjusted Bayesian (BIC)         7628.103    7628.103
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.126       0.117
#   90 Percent confidence interval - lower         0.097       0.089
#   90 Percent confidence interval - upper         0.158       0.146
#   P-value RMSEA <= 0.05                          0.000       0.000
#
#   Robust RMSEA                                               0.125
#   90 Percent confidence interval - lower                     0.093
#   90 Percent confidence interval - upper                     0.159
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.068       0.068
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q34_1             1.000                               1.178    0.697
#     Q34_4             0.659    0.096    6.892    0.000    0.777    0.517
#     Q34_5             1.080    0.118    9.136    0.000    1.273    0.842
#   Affect =~
#     Q34_7             1.000                               1.225    0.825
#     Q34_11            0.935    0.052   17.998    0.000    1.145    0.871
#     Q34_14            0.699    0.063   11.187    0.000    0.857    0.709
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            0.801    0.133    6.018    0.000    0.555    0.555
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q34_1             1.468    0.168    8.741    0.000    1.468    0.514
#    .Q34_4             1.654    0.180    9.213    0.000    1.654    0.733
#    .Q34_5             0.666    0.158    4.210    0.000    0.666    0.291
#    .Q34_7             0.706    0.098    7.176    0.000    0.706    0.320
#    .Q34_11            0.416    0.068    6.106    0.000    0.416    0.241
#    .Q34_14            0.724    0.109    6.651    0.000    0.724    0.497
#     Cognition         1.389    0.215    6.470    0.000    1.000    1.000
#     Affect            1.501    0.147   10.204    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q34_1             0.486
#     Q34_4             0.267
#     Q34_5             0.709
#     Q34_7             0.680
#     Q34_11            0.759
#     Q34_14            0.503

# %%
resid(prebiofit)
# Out:
# $type
# [1] "raw"
#
# $cov
#        Q34_1  Q34_4  Q34_5  Q34_7  Q34_11 Q34_14
# Q34_1   0.000
# Q34_4   0.094  0.000
# Q34_5  -0.057  0.057  0.000
# Q34_7   0.224 -0.439  0.046  0.000
# Q34_11 -0.002 -0.352 -0.015  0.014  0.000
# Q34_14  0.196 -0.042  0.120 -0.041  0.005  0.000

# %%
alpha(BioAttPreSubset[c('Q34_1', 'Q34_4', 'Q34_5')])
# Out:
# Reliability analysis
# Call: alpha(x = BioAttPreSubset[c("Q34_1", "Q34_4", "Q34_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.73      0.73    0.65      0.47 2.7 0.024  3.7 1.3     0.46
#
#  lower alpha upper     95% confidence boundaries
# 0.68 0.73 0.78
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q34_1      0.63      0.63    0.46      0.46 1.7    0.037    NA  0.46
# Q34_4      0.72      0.72    0.56      0.56 2.6    0.028    NA  0.56
# Q34_5      0.57      0.57    0.40      0.40 1.3    0.043    NA  0.40
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q34_1 394  0.83  0.81  0.67   0.56  3.9 1.7
# Q34_4 394  0.76  0.77  0.56   0.48  3.2 1.5
# Q34_5 394  0.83  0.84  0.72   0.62  3.9 1.5
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q34_1 0.09 0.13 0.20 0.19 0.20 0.12 0.07    0
# Q34_4 0.14 0.20 0.28 0.18 0.12 0.06 0.02    0
# Q34_5 0.06 0.11 0.27 0.22 0.19 0.11 0.04    0

# %%
alpha(BioAttPreSubset[c('Q34_7', 'Q34_11', 'Q34_14')])
# Out:
# Reliability analysis
# Call: alpha(x = BioAttPreSubset[c("Q34_7", "Q34_11", "Q34_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.84      0.84    0.79      0.64 5.3 0.014  4.8 1.2     0.62
#
#  lower alpha upper     95% confidence boundaries
# 0.81 0.84 0.87
#
#  Reliability if an item is dropped:
#        raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q34_7       0.76      0.77    0.62      0.62 3.3    0.024    NA  0.62
# Q34_11      0.71      0.72    0.56      0.56 2.6    0.028    NA  0.56
# Q34_14      0.84      0.84    0.73      0.73 5.3    0.016    NA  0.73
#
#  Item statistics
#          n raw.r std.r r.cor r.drop mean  sd
# Q34_7  394  0.89  0.88  0.79   0.72  5.0 1.5
# Q34_11 394  0.90  0.90  0.84   0.77  4.9 1.3
# Q34_14 394  0.82  0.84  0.69   0.64  4.7 1.2
#
# Non missing response frequency for each item
#           1    2    3    4    5    6    7 miss
# Q34_7  0.02 0.04 0.08 0.24 0.26 0.16 0.20    0
# Q34_11 0.01 0.03 0.06 0.33 0.25 0.18 0.14    0
# Q34_14 0.01 0.03 0.07 0.36 0.29 0.16 0.07    0

# %%
BioAttPostSubset<-PostSurveyChemData[-1,c('Q34_1', 'Q34_4', 'Q34_5', 'Q34_7', 'Q34_11', 'Q34_14')]
BioAttPostSubset<-na.omit(BioAttPostSubset)
BioAttPostSubset<-as.data.frame(sapply(BioAttPostSubset,as.numeric))

# %%
BioAttPostSubset["Q34_1"]<-(BioAttPostSubset["Q34_1"] - 8)*-1
BioAttPostSubset["Q34_7"]<-(BioAttPostSubset["Q34_7"] - 8)*-1
BioAttPostSubset["Q34_11"]<-(BioAttPostSubset["Q34_11"] - 8)*-1
BioAttPostSubset["Q34_14"]<-(BioAttPostSubset["Q34_14"] - 8)*-1

# %%
postbiofit.model<-'Cognition =~ Q34_1 + Q34_4 + Q34_5
                Affect =~ Q34_7 + Q34_11 + Q34_14'

# %%
postbiofit <- cfa(postbiofit.model, data=BioAttPostSubset, estimator="MLR")

# %%
summary(postbiofit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 31 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           204
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 22.493      13.792
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.004       0.087
#   Scaling correction factor                                   1.631
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                               610.131     348.916
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.749
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.976       0.983
#   Tucker-Lewis Index (TLI)                       0.954       0.967
#
#   Robust Comparative Fit Index (CFI)                         0.984
#   Robust Tucker-Lewis Index (TLI)                            0.970
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -1953.128   -1953.128
#   Scaling correction factor                                  1.399
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -1941.882   -1941.882
#   Scaling correction factor                                  1.487
#       for the MLR correction
#
#   Akaike (AIC)                                3932.256    3932.256
#   Bayesian (BIC)                              3975.391    3975.391
#   Sample-size adjusted Bayesian (BIC)         3934.203    3934.203
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.094       0.060
#   90 Percent confidence interval - lower         0.049       0.004
#   90 Percent confidence interval - upper         0.141       0.100
#   P-value RMSEA <= 0.05                          0.052       0.315
#
#   Robust RMSEA                                               0.076
#   90 Percent confidence interval - lower                        NA
#   90 Percent confidence interval - upper                     0.142
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.044       0.044
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q34_1             1.000                               1.194    0.729
#     Q34_4             1.150    0.110   10.421    0.000    1.373    0.818
#     Q34_5             1.177    0.118    9.986    0.000    1.406    0.879
#   Affect =~
#     Q34_7             1.000                               1.170    0.796
#     Q34_11            1.015    0.087   11.618    0.000    1.188    0.835
#     Q34_14            0.887    0.091    9.766    0.000    1.038    0.784
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            0.827    0.184    4.506    0.000    0.592    0.592
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q34_1             1.260    0.203    6.215    0.000    1.260    0.469
#    .Q34_4             0.932    0.223    4.174    0.000    0.932    0.331
#    .Q34_5             0.584    0.150    3.897    0.000    0.584    0.228
#    .Q34_7             0.793    0.145    5.489    0.000    0.793    0.367
#    .Q34_11            0.610    0.118    5.170    0.000    0.610    0.302
#    .Q34_14            0.678    0.147    4.624    0.000    0.678    0.386
#     Cognition         1.426    0.257    5.552    0.000    1.000    1.000
#     Affect            1.370    0.224    6.105    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q34_1             0.531
#     Q34_4             0.669
#     Q34_5             0.772
#     Q34_7             0.633
#     Q34_11            0.698
#     Q34_14            0.614

# %%
describe(BioAttPostSubset)
# Out:
#        vars n   mean     sd       median trimmed  mad    min max range
# Q34_1  1    204 3.926471 1.642863 4      3.878049 1.4826 1   7   6
# Q34_4  2    204 3.539216 1.682548 3      3.451220 1.4826 1   7   6
# Q34_5  3    204 3.936275 1.603831 4      3.896341 1.4826 1   7   6
# Q34_7  4    204 4.666667 1.474468 5      4.701220 1.4826 1   7   6
# Q34_11 5    204 4.750000 1.425057 5      4.786585 1.4826 1   7   6
# Q34_14 6    204 4.563725 1.328304 4      4.560976 1.4826 1   7   6
#        skew       kurtosis   se
# Q34_1   0.1967165 -0.6370008 0.11502345
# Q34_4   0.4140963 -0.5740102 0.11780190
# Q34_5   0.1816536 -0.6638921 0.11229063
# Q34_7  -0.1607357 -0.3956798 0.10323341
# Q34_11 -0.1162399 -0.2364927 0.09977396
# Q34_14 -0.1365324  0.3613067 0.09299989

# %%
alpha(BioAttPostSubset[c('Q34_1', 'Q34_4', 'Q34_5')])
# Out:
# Reliability analysis
# Call: alpha(x = BioAttPostSubset[c("Q34_1", "Q34_4", "Q34_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.85      0.85     0.8      0.65 5.7 0.018  3.8 1.4     0.63
#
#  lower alpha upper     95% confidence boundaries
# 0.81 0.85 0.89
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q34_1      0.84      0.84    0.72      0.72 5.3    0.022    NA  0.72
# Q34_4      0.76      0.76    0.61      0.61 3.1    0.034    NA  0.61
# Q34_5      0.77      0.77    0.63      0.63 3.3    0.032    NA  0.63
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q34_1 204  0.85  0.85  0.72   0.67  3.9 1.6
# Q34_4 204  0.90  0.89  0.82   0.75  3.5 1.7
# Q34_5 204  0.89  0.89  0.81   0.74  3.9 1.6
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q34_1 0.07 0.13 0.20 0.28 0.13 0.09 0.09    0
# Q34_4 0.11 0.20 0.22 0.21 0.13 0.05 0.08    0
# Q34_5 0.06 0.13 0.22 0.25 0.15 0.11 0.08    0

# %%
alpha(BioAttPostSubset[c('Q34_7', 'Q34_11', 'Q34_14')])
# Out:
# Reliability analysis
# Call: alpha(x = BioAttPostSubset[c("Q34_7", "Q34_11", "Q34_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.84      0.85    0.79      0.65 5.5 0.019  4.7 1.2     0.67
#
#  lower alpha upper     95% confidence boundaries
# 0.81 0.84 0.88
#
#  Reliability if an item is dropped:
#        raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q34_7       0.80      0.80    0.67      0.67 4.0    0.028    NA  0.67
# Q34_11      0.75      0.75    0.60      0.60 3.0    0.035    NA  0.60
# Q34_14      0.80      0.80    0.67      0.67 4.1    0.028    NA  0.67
#
#  Item statistics
#          n raw.r std.r r.cor r.drop mean  sd
# Q34_7  204  0.87  0.87  0.76   0.70  4.7 1.5
# Q34_11 204  0.89  0.89  0.81   0.75  4.8 1.4
# Q34_14 204  0.86  0.86  0.75   0.69  4.6 1.3
#
# Non missing response frequency for each item
#           1    2    3    4    5    6    7 miss
# Q34_7  0.02 0.04 0.12 0.30 0.23 0.15 0.14    0
# Q34_11 0.02 0.04 0.08 0.34 0.25 0.12 0.16    0
# Q34_14 0.03 0.02 0.09 0.38 0.26 0.11 0.10    0
