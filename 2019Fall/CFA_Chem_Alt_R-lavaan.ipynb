# %%
library(lavaan)
library(readxl)
library(psych)
# Out:
# This is lavaan 0.6-6
# lavaan is BETA software! Please report any bugs.
#
# Attaching package: ‘psych’
#
# The following object is masked from ‘package:lavaan’:
#
#     cor2cov

# %%
path = "/Users/erikmenke/UC-Merced/Data/2019-2020/NSF HSI/Fall 2019/Survey/Postterm/"
PreSurveyChemDataFilename = "Chem Attitudes_Pre-Fall 2019.xlsx"
PostSurveyChemDataFilename = "Chem Attitudes_Post-Fall 2019.xlsx"

PreSurveyChemData <- read_excel(paste(path, PreSurveyChemDataFilename, sep=""))
PostSurveyChemData <- read_excel(paste(path, PostSurveyChemDataFilename, sep=""))
# Out:
# New names:
# * Q35 -> Q35...1
# * Q35 -> Q35...96
# New names:
# * Q35 -> Q35...1
# * Q35 -> Q35...96

# %%
describe(PreSurveyChemData[-1,c('Q1_1', 'Q1_2', 'Q1_3', 'Q1_4', 'Q1_5',
                                'Q1_6', 'Q1_7', 'Q1_8', 'Q1_9', 'Q1_10',
                                'Q1_11', 'Q1_12', 'Q1_13', 'Q1_14', 'Q1_15',
                                'Q1_16', 'Q1_17', 'Q1_18', 'Q1_19', 'Q1_20'
                               )])
# Out:
#        vars n   mean     sd       median trimmed  mad    min max range
# Q1_1*   1   401 4.758105 1.396009 5      4.803738 1.4826 1   7   6
# Q1_2*   2   401 5.668329 1.285387 6      5.822430 1.4826 1   7   6
# Q1_3*   3   401 3.394015 1.516365 3      3.330218 1.4826 1   7   6
# Q1_4*   4   401 2.817955 1.299722 3      2.725857 1.4826 1   7   6
# Q1_5*   5   401 3.354115 1.359886 3      3.339564 1.4826 1   7   6
# Q1_6*   6   401 2.730673 1.420310 3      2.619938 1.4826 1   7   6
# Q1_7*   7   401 3.812968 1.611655 4      3.785047 1.4826 1   7   6
# Q1_8*   8   401 4.127182 1.502093 4      4.143302 1.4826 1   7   6
# Q1_9*   9   401 3.408978 1.375616 3      3.352025 1.4826 1   7   6
# Q1_10* 10   401 2.329177 1.136385 2      2.214953 1.4826 1   7   6
# Q1_11* 11   401 3.695761 1.399002 4      3.672897 1.4826 1   7   6
# Q1_12* 12   401 2.770574 1.400797 3      2.632399 1.4826 1   7   6
# Q1_13* 13   401 4.551122 1.270041 4      4.548287 1.4826 1   7   6
# Q1_14* 14   401 3.875312 1.313169 4      3.875389 1.4826 1   7   6
# Q1_15* 15   401 2.665835 1.279865 3      2.591900 1.4826 1   7   6
# Q1_16* 16   401 2.351621 1.307117 2      2.227414 1.4826 1   7   6
# Q1_17* 17   401 4.326683 1.544510 4      4.361371 1.4826 1   7   6
# Q1_18* 18   401 3.748130 1.417358 4      3.772586 1.4826 1   7   6
# Q1_19* 19   401 3.174564 1.290136 3      3.146417 1.4826 1   7   6
# Q1_20* 20   401 4.122195 1.335115 4      4.158879 1.4826 1   7   6
#        skew         kurtosis     se
# Q1_1*  -0.351640699 -0.241768039 0.06971335
# Q1_2*  -1.029540695  1.133454342 0.06418916
# Q1_3*   0.309185717 -0.272655908 0.07572368
# Q1_4*   0.509350543  0.003322887 0.06490501
# Q1_5*   0.224465627 -0.163042199 0.06790945
# Q1_6*   0.522053086 -0.160948702 0.07092692
# Q1_7*   0.168342426 -0.652901687 0.08048220
# Q1_8*  -0.066351957 -0.212144421 0.07501096
# Q1_9*   0.396485756 -0.066643626 0.06869498
# Q1_10*  0.903347249  1.054756772 0.05674837
# Q1_11*  0.112791167  0.002737325 0.06986283
# Q1_12*  0.764878987  0.465492920 0.06995246
# Q1_13* -0.117934449  0.595990239 0.06342284
# Q1_14* -0.007935291  0.082790655 0.06557655
# Q1_15*  0.618322772  0.549183355 0.06391342
# Q1_16*  0.760041589 -0.011256787 0.06527428
# Q1_17* -0.216688067 -0.498736362 0.07712915
# Q1_18* -0.129108067 -0.055567876 0.07077946
# Q1_19*  0.294048641  0.030884017 0.06442633
# Q1_20* -0.154149793  0.556062337 0.06667244

# %%
ChemAttPreSubset<-PreSurveyChemData[-1,c('Q1_1', 'Q1_4', 'Q1_5', 'Q1_7', 'Q1_11', 'Q1_14')]
ChemAttPreSubset<-na.omit(ChemAttPreSubset)
ChemAttPreSubset<-as.data.frame(sapply(ChemAttPreSubset,as.numeric))

# %%
ChemAttPreSubset["Q1_1"]<-(ChemAttPreSubset["Q1_1"] - 8)*-1
ChemAttPreSubset["Q1_7"]<-(ChemAttPreSubset["Q1_7"] - 8)*-1
ChemAttPreSubset["Q1_11"]<-(ChemAttPreSubset["Q1_11"] - 8)*-1
ChemAttPreSubset["Q1_14"]<-(ChemAttPreSubset["Q1_14"] - 8)*-1

# %%
describe(ChemAttPreSubset)
# Out:
#       vars n   mean     sd       median trimmed  mad    min max range
# Q1_1  1    401 3.241895 1.396009 3      3.196262 1.4826 1   7   6
# Q1_4  2    401 2.817955 1.299722 3      2.725857 1.4826 1   7   6
# Q1_5  3    401 3.354115 1.359886 3      3.339564 1.4826 1   7   6
# Q1_7  4    401 4.187032 1.611655 4      4.214953 1.4826 1   7   6
# Q1_11 5    401 4.304239 1.399002 4      4.327103 1.4826 1   7   6
# Q1_14 6    401 4.124688 1.313169 4      4.124611 1.4826 1   7   6
#       skew         kurtosis     se
# Q1_1   0.351640699 -0.241768039 0.06971335
# Q1_4   0.509350543  0.003322887 0.06490501
# Q1_5   0.224465627 -0.163042199 0.06790945
# Q1_7  -0.168342426 -0.652901687 0.08048220
# Q1_11 -0.112791167  0.002737325 0.06986283
# Q1_14  0.007935291  0.082790655 0.06557655

# %%
prechemfit.model<-'Cognition =~ Q1_1 + Q1_4 + Q1_5
                Affect =~ Q1_7 + Q1_11 + Q1_14'

#prechemfit.model<-'Cognition =~ Q1_1 + Q1_4 + Q1_5 + Q1_7 + Q1_11 + Q1_14'

# %%
prechemfit <- cfa(prechemfit.model, data=ChemAttPreSubset, estimator="MLR")

# %%
summary(prechemfit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 30 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           401
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 64.877      56.711
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.000       0.000
#   Scaling correction factor                                   1.144
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                              1158.954     910.921
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.272
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.950       0.946
#   Tucker-Lewis Index (TLI)                       0.907       0.898
#
#   Robust Comparative Fit Index (CFI)                         0.951
#   Robust Tucker-Lewis Index (TLI)                            0.908
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -3661.366   -3661.366
#   Scaling correction factor                                  1.192
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -3628.927   -3628.927
#   Scaling correction factor                                  1.173
#       for the MLR correction
#
#   Akaike (AIC)                                7348.731    7348.731
#   Bayesian (BIC)                              7400.653    7400.653
#   Sample-size adjusted Bayesian (BIC)         7359.403    7359.403
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.133       0.123
#   90 Percent confidence interval - lower         0.104       0.096
#   90 Percent confidence interval - upper         0.164       0.152
#   P-value RMSEA <= 0.05                          0.000       0.000
#
#   Robust RMSEA                                               0.132
#   90 Percent confidence interval - lower                     0.101
#   90 Percent confidence interval - upper                     0.165
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.055       0.055
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q1_1              1.000                               1.025    0.735
#     Q1_4              0.902    0.073   12.291    0.000    0.925    0.712
#     Q1_5              1.134    0.093   12.190    0.000    1.162    0.856
#   Affect =~
#     Q1_7              1.000                               1.227    0.762
#     Q1_11             0.985    0.058   16.840    0.000    1.209    0.865
#     Q1_14             0.853    0.064   13.239    0.000    1.047    0.798
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            0.859    0.120    7.156    0.000    0.683    0.683
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q1_1              0.893    0.119    7.478    0.000    0.893    0.460
#    .Q1_4              0.830    0.087    9.493    0.000    0.830    0.492
#    .Q1_5              0.494    0.086    5.738    0.000    0.494    0.268
#    .Q1_7              1.085    0.136    7.970    0.000    1.085    0.419
#    .Q1_11             0.492    0.069    7.090    0.000    0.492    0.252
#    .Q1_14             0.624    0.069    9.000    0.000    0.624    0.363
#     Cognition         1.051    0.139    7.560    0.000    1.000    1.000
#     Affect            1.506    0.175    8.588    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q1_1              0.540
#     Q1_4              0.508
#     Q1_5              0.732
#     Q1_7              0.581
#     Q1_11             0.748
#     Q1_14             0.637

# %%
resid(prechemfit)
# Out:
# $type
# [1] "raw"
#
# $cov
#       Q1_1   Q1_4   Q1_5   Q1_7   Q1_11  Q1_14
# Q1_1   0.000
# Q1_4   0.036  0.000
# Q1_5  -0.068  0.052  0.000
# Q1_7   0.183 -0.175  0.147  0.000
# Q1_11  0.093 -0.249 -0.077  0.031  0.000
# Q1_14  0.182 -0.125  0.087 -0.086  0.019  0.000

# %%
alpha(ChemAttPreSubset[c('Q1_1', 'Q1_4', 'Q1_5')])
# Out:
# Reliability analysis
# Call: alpha(x = ChemAttPreSubset[c("Q1_1", "Q1_4", "Q1_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.81      0.81    0.75      0.59 4.4 0.016  3.1 1.2     0.59
#
#  lower alpha upper     95% confidence boundaries
# 0.78 0.81 0.84
#
#  Reliability if an item is dropped:
#      raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q1_1      0.78      0.78    0.64      0.64 3.5    0.022    NA  0.64
# Q1_4      0.74      0.74    0.59      0.59 2.9    0.025    NA  0.59
# Q1_5      0.70      0.70    0.54      0.54 2.4    0.030    NA  0.54
#
#  Item statistics
#        n raw.r std.r r.cor r.drop mean  sd
# Q1_1 401  0.84  0.83  0.69   0.63  3.2 1.4
# Q1_4 401  0.85  0.85  0.74   0.66  2.8 1.3
# Q1_5 401  0.87  0.87  0.78   0.70  3.4 1.4
#
# Non missing response frequency for each item
#         1    2    3    4    5    6    7 miss
# Q1_1 0.11 0.19 0.30 0.23 0.10 0.05 0.01    0
# Q1_4 0.17 0.24 0.31 0.17 0.07 0.02 0.01    0
# Q1_5 0.10 0.14 0.32 0.26 0.11 0.05 0.01    0

# %%
alpha(ChemAttPreSubset[c('Q1_7', 'Q1_11', 'Q1_14')])
# Out:
# Reliability analysis
# Call: alpha(x = ChemAttPreSubset[c("Q1_7", "Q1_11", "Q1_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.84      0.85    0.79      0.65 5.5 0.014  4.2 1.3     0.67
#
#  lower alpha upper     95% confidence boundaries
# 0.81 0.84 0.87
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q1_7       0.82      0.82    0.70      0.70 4.7    0.018    NA  0.70
# Q1_11      0.71      0.72    0.57      0.57 2.6    0.028    NA  0.57
# Q1_14      0.80      0.80    0.67      0.67 4.1    0.020    NA  0.67
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q1_7  401  0.87  0.85  0.73   0.67  4.2 1.6
# Q1_11 401  0.90  0.90  0.85   0.77  4.3 1.4
# Q1_14 401  0.85  0.86  0.76   0.69  4.1 1.3
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q1_7  0.06 0.10 0.16 0.23 0.23 0.13 0.08    0
# Q1_11 0.04 0.06 0.13 0.35 0.24 0.10 0.08    0
# Q1_14 0.03 0.08 0.16 0.37 0.23 0.07 0.05    0

# %%
ChemAttPostSubset<-PostSurveyChemData[-1,c('Q1_1', 'Q1_4', 'Q1_5', 'Q1_7', 'Q1_11', 'Q1_14')]
ChemAttPostSubset<-na.omit(ChemAttPostSubset)
ChemAttPostSubset<-as.data.frame(sapply(ChemAttPostSubset,as.numeric))

# %%
ChemAttPostSubset["Q1_1"]<-(ChemAttPostSubset["Q1_1"] - 8)*-1
ChemAttPostSubset["Q1_7"]<-(ChemAttPostSubset["Q1_7"] - 8)*-1
ChemAttPostSubset["Q1_11"]<-(ChemAttPostSubset["Q1_11"] - 8)*-1
ChemAttPostSubset["Q1_14"]<-(ChemAttPostSubset["Q1_14"] - 8)*-1

# %%
postchemfit.model<-'Cognition =~ Q1_1 + Q1_4 + Q1_5
                Affect =~ Q1_7 + Q1_11 + Q1_14'

# %%
postchemfit <- cfa(postchemfit.model, data=ChemAttPostSubset, estimator="MLR")

# %%
summary(postchemfit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 34 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           210
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 42.601      38.438
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.000       0.000
#   Scaling correction factor                                   1.108
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                               510.776     374.142
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.365
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.930       0.915
#   Tucker-Lewis Index (TLI)                       0.869       0.841
#
#   Robust Comparative Fit Index (CFI)                         0.931
#   Robust Tucker-Lewis Index (TLI)                            0.871
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -2075.583   -2075.583
#   Scaling correction factor                                  1.305
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -2054.282   -2054.282
#   Scaling correction factor                                  1.230
#       for the MLR correction
#
#   Akaike (AIC)                                4177.166    4177.166
#   Bayesian (BIC)                              4220.679    4220.679
#   Sample-size adjusted Bayesian (BIC)         4179.487    4179.487
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.144       0.135
#   90 Percent confidence interval - lower         0.103       0.096
#   90 Percent confidence interval - upper         0.187       0.176
#   P-value RMSEA <= 0.05                          0.000       0.000
#
#   Robust RMSEA                                               0.142
#   90 Percent confidence interval - lower                     0.099
#   90 Percent confidence interval - upper                     0.188
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.071       0.071
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q1_1              1.000                               0.924    0.606
#     Q1_4              1.067    0.192    5.542    0.000    0.986    0.703
#     Q1_5              1.374    0.274    5.014    0.000    1.270    0.863
#   Affect =~
#     Q1_7              1.000                               1.470    0.822
#     Q1_11             0.842    0.057   14.700    0.000    1.238    0.815
#     Q1_14             0.670    0.082    8.154    0.000    0.984    0.700
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            0.870    0.234    3.723    0.000    0.640    0.640
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q1_1              1.469    0.245    5.989    0.000    1.469    0.632
#    .Q1_4              0.994    0.178    5.571    0.000    0.994    0.506
#    .Q1_5              0.552    0.186    2.973    0.003    0.552    0.255
#    .Q1_7              1.038    0.189    5.490    0.000    1.038    0.325
#    .Q1_11             0.772    0.128    6.016    0.000    0.772    0.335
#    .Q1_14             1.008    0.172    5.875    0.000    1.008    0.510
#     Cognition         0.854    0.277    3.086    0.002    1.000    1.000
#     Affect            2.160    0.283    7.627    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q1_1              0.368
#     Q1_4              0.494
#     Q1_5              0.745
#     Q1_7              0.675
#     Q1_11             0.665
#     Q1_14             0.490

# %%
describe(ChemAttPostSubset)
# Out:
#       vars n   mean     sd       median trimmed  mad    min max range
# Q1_1  1    210 3.219048 1.527928 3      3.113095 1.4826 1   7   6
# Q1_4  2    210 2.976190 1.405527 3      2.875000 1.4826 1   7   6
# Q1_5  3    210 3.485714 1.474597 3      3.422619 1.4826 1   7   6
# Q1_7  4    210 4.200000 1.792595 4      4.238095 1.4826 1   7   6
# Q1_11 5    210 4.385714 1.521390 4      4.398810 1.4826 1   7   6
# Q1_14 6    210 4.180952 1.409340 4      4.190476 1.4826 1   7   6
#       skew        kurtosis    se
# Q1_1   0.58359255 -0.07654046 0.10543704
# Q1_4   0.69027577  0.37492799 0.09699060
# Q1_5   0.33523157 -0.22185290 0.10175686
# Q1_7  -0.06666296 -0.92155427 0.12370081
# Q1_11 -0.07954910 -0.48169153 0.10498588
# Q1_14 -0.02483150 -0.12873667 0.09725368

# %%
alpha(ChemAttPostSubset[c('Q1_1', 'Q1_4', 'Q1_5')])
# Out:
# Reliability analysis
# Call: alpha(x = ChemAttPostSubset[c("Q1_1", "Q1_4", "Q1_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.76      0.76    0.69      0.52 3.2 0.029  3.2 1.2     0.49
#
#  lower alpha upper     95% confidence boundaries
# 0.7 0.76 0.82
#
#  Reliability if an item is dropped:
#      raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q1_1      0.77      0.77    0.63      0.63 3.4    0.031    NA  0.63
# Q1_4      0.65      0.65    0.49      0.49 1.9    0.048    NA  0.49
# Q1_5      0.60      0.60    0.43      0.43 1.5    0.055    NA  0.43
#
#  Item statistics
#        n raw.r std.r r.cor r.drop mean  sd
# Q1_1 210  0.79  0.78  0.57   0.51  3.2 1.5
# Q1_4 210  0.83  0.84  0.72   0.61  3.0 1.4
# Q1_5 210  0.86  0.86  0.76   0.66  3.5 1.5
#
# Non missing response frequency for each item
#         1    2    3    4    5    6    7 miss
# Q1_1 0.13 0.21 0.29 0.20 0.10 0.04 0.04    0
# Q1_4 0.15 0.24 0.31 0.17 0.09 0.02 0.03    0
# Q1_5 0.09 0.17 0.25 0.29 0.10 0.06 0.04    0

# %%
alpha(ChemAttPostSubset[c('Q1_7', 'Q1_11', 'Q1_14')])
# Out:
# Reliability analysis
# Call: alpha(x = ChemAttPostSubset[c("Q1_7", "Q1_11", "Q1_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.81      0.82    0.76       0.6 4.5 0.022  4.3 1.4     0.58
#
#  lower alpha upper     95% confidence boundaries
# 0.77 0.81 0.86
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q1_7       0.73      0.73    0.58      0.58 2.7    0.037    NA  0.58
# Q1_11      0.68      0.70    0.53      0.53 2.3    0.042    NA  0.53
# Q1_14      0.81      0.82    0.69      0.69 4.5    0.025    NA  0.69
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q1_7  210  0.89  0.87  0.77   0.69  4.2 1.8
# Q1_11 210  0.88  0.88  0.81   0.73  4.4 1.5
# Q1_14 210  0.80  0.82  0.66   0.60  4.2 1.4
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q1_7  0.09 0.08 0.20 0.20 0.17 0.13 0.13    0
# Q1_11 0.03 0.08 0.14 0.29 0.22 0.12 0.11    0
# Q1_14 0.04 0.08 0.16 0.36 0.20 0.10 0.07    0
