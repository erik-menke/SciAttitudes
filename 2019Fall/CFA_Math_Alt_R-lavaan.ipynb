# %%
library(lavaan)
library(readxl)
library(psych)
# Out:
# This is lavaan 0.6-6
# lavaan is BETA software! Please report any bugs.
#
# Attaching package: ‘psych’
#
# The following object is masked from ‘package:lavaan’:
#
#     cor2cov

# %%
path = "/Users/erikmenke/UC-Merced/Data/2019-2020/NSF HSI/Fall 2019/Survey/Postterm/"
PreSurveyChemDataFilename = "Chem Attitudes_Pre-Fall 2019.xlsx"
PostSurveyChemDataFilename = "Chem Attitudes_Post-Fall 2019.xlsx"

PreSurveyChemData <- read_excel(paste(path, PreSurveyChemDataFilename, sep=""))
PostSurveyChemData <- read_excel(paste(path, PostSurveyChemDataFilename, sep=""))
# Out:
# New names:
# * Q35 -> Q35...1
# * Q35 -> Q35...96
# New names:
# * Q35 -> Q35...1
# * Q35 -> Q35...96

# %%
describe(PreSurveyChemData[-1,c('Q32_1', 'Q32_2', 'Q32_3', 'Q32_4', 'Q32_5',
                                'Q32_6', 'Q32_7', 'Q32_8', 'Q32_9', 'Q32_10',
                                'Q32_11', 'Q32_12', 'Q32_13', 'Q32_14', 'Q32_15',
                                'Q32_16', 'Q32_17', 'Q32_18', 'Q32_19', 'Q32_20'
                               )])
# Out:
#         vars n   mean     sd       median trimmed  mad    min max range
# Q32_1*   1   389 4.508997 1.889484 5      4.610224 2.9652 1   7   6
# Q32_2*   2   389 5.763496 1.466324 6      6.022364 1.4826 1   7   6
# Q32_3*   3   389 3.637532 1.704975 4      3.600639 1.4826 1   7   6
# Q32_4*   4   389 2.933162 1.571543 3      2.776358 1.4826 1   7   6
# Q32_5*   5   389 3.449871 1.649955 3      3.376997 1.4826 1   7   6
# Q32_6*   6   389 2.696658 1.414401 3      2.581470 1.4826 1   7   6
# Q32_7*   7   389 3.462725 1.898663 3      3.354633 2.9652 1   7   6
# Q32_8*   8   389 4.025707 1.647978 4      4.003195 1.4826 1   7   6
# Q32_9*   9   389 3.267352 1.524876 3      3.188498 1.4826 1   7   6
# Q32_10* 10   389 2.305913 1.324430 2      2.127796 1.4826 1   7   6
# Q32_11* 11   389 3.588689 1.564910 4      3.562300 1.4826 1   7   6
# Q32_12* 12   389 3.298201 1.616131 3      3.194888 1.4826 1   7   6
# Q32_13* 13   389 4.287918 1.408510 4      4.306709 1.4826 1   7   6
# Q32_14* 14   389 3.740360 1.515195 4      3.744409 1.4826 1   7   6
# Q32_15* 15   389 2.591260 1.480118 2      2.412141 1.4826 1   7   6
# Q32_16* 16   389 2.293059 1.347574 2      2.150160 1.4826 1   7   6
# Q32_17* 17   389 4.282776 1.789787 4      4.345048 1.4826 1   7   6
# Q32_18* 18   389 3.025707 1.556283 4      2.936102 1.4826 1   7   6
# Q32_19* 19   389 3.290488 1.494125 3      3.233227 1.4826 1   7   6
# Q32_20* 20   389 4.197943 1.517729 4      4.214058 1.4826 1   7   6
#         skew        kurtosis    se
# Q32_1*  -0.33173941 -1.03739284 0.09580066
# Q32_2*  -1.37387493  1.56468490 0.07434560
# Q32_3*   0.14937828 -0.81552286 0.08644564
# Q32_4*   0.72608174 -0.12091481 0.07968040
# Q32_5*   0.43840488 -0.66282195 0.08365604
# Q32_6*   0.69703654  0.30871571 0.07171297
# Q32_7*   0.30640345 -1.03821356 0.09626604
# Q32_8*   0.12103694 -0.57136540 0.08355581
# Q32_9*   0.45020155 -0.25135516 0.07731427
# Q32_10*  1.09464075  1.04783635 0.06715126
# Q32_11*  0.05335377 -0.49878782 0.07934410
# Q32_12*  0.39286187 -0.43651888 0.08194108
# Q32_13* -0.07558536  0.29649081 0.07141428
# Q32_14*  0.03521524 -0.41094067 0.07682343
# Q32_15*  0.84501359  0.26238163 0.07504494
# Q32_16*  0.81386597 -0.02225601 0.06832474
# Q32_17* -0.12338505 -0.78377027 0.09074579
# Q32_18*  0.17835640 -0.59267054 0.07890670
# Q32_19*  0.25635538 -0.20257973 0.07575514
# Q32_20* -0.05791105  0.06027381 0.07695191

# %%
MathAttPreSubset<-PreSurveyChemData[-1,c('Q32_1', 'Q32_4', 'Q32_5', 'Q32_7', 'Q32_11', 'Q32_14')]
MathAttPreSubset<-na.omit(MathAttPreSubset)
MathAttPreSubset<-as.data.frame(sapply(MathAttPreSubset,as.numeric))

# %%
MathAttPreSubset["Q32_1"]<-(MathAttPreSubset["Q32_1"] - 8)*-1
MathAttPreSubset["Q32_7"]<-(MathAttPreSubset["Q32_7"] - 8)*-1
MathAttPreSubset["Q32_11"]<-(MathAttPreSubset["Q32_11"] - 8)*-1
MathAttPreSubset["Q32_14"]<-(MathAttPreSubset["Q32_14"] - 8)*-1

# %%
describe(MathAttPreSubset)
# Out:
#        vars n   mean     sd       median trimmed  mad    min max range
# Q32_1  1    389 3.491003 1.889484 3      3.389776 2.9652 1   7   6
# Q32_4  2    389 2.933162 1.571543 3      2.776358 1.4826 1   7   6
# Q32_5  3    389 3.449871 1.649955 3      3.376997 1.4826 1   7   6
# Q32_7  4    389 4.537275 1.898663 5      4.645367 2.9652 1   7   6
# Q32_11 5    389 4.411311 1.564910 4      4.437700 1.4826 1   7   6
# Q32_14 6    389 4.259640 1.515195 4      4.255591 1.4826 1   7   6
#        skew        kurtosis   se
# Q32_1   0.33173941 -1.0373928 0.09580066
# Q32_4   0.72608174 -0.1209148 0.07968040
# Q32_5   0.43840488 -0.6628220 0.08365604
# Q32_7  -0.30640345 -1.0382136 0.09626604
# Q32_11 -0.05335377 -0.4987878 0.07934410
# Q32_14 -0.03521524 -0.4109407 0.07682343

# %%
premathfit.model<-'Cognition =~ Q32_1 + Q32_4 + Q32_5
                Affect =~ Q32_7 + Q32_11 + Q32_14'

# %%
premathfit <- cfa(premathfit.model, data=MathAttPreSubset, estimator="MLR")

# %%
summary(premathfit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 33 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           389
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 73.898      55.363
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.000       0.000
#   Scaling correction factor                                   1.335
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                              1179.315     768.366
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.535
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.943       0.937
#   Tucker-Lewis Index (TLI)                       0.894       0.882
#
#   Robust Comparative Fit Index (CFI)                         0.945
#   Robust Tucker-Lewis Index (TLI)                            0.897
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -3959.513   -3959.513
#   Scaling correction factor                                  1.269
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -3922.564   -3922.564
#   Scaling correction factor                                  1.294
#       for the MLR correction
#
#   Akaike (AIC)                                7945.026    7945.026
#   Bayesian (BIC)                              7996.553    7996.553
#   Sample-size adjusted Bayesian (BIC)         7955.305    7955.305
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.146       0.123
#   90 Percent confidence interval - lower         0.116       0.098
#   90 Percent confidence interval - upper         0.177       0.151
#   P-value RMSEA <= 0.05                          0.000       0.000
#
#   Robust RMSEA                                               0.143
#   90 Percent confidence interval - lower                     0.108
#   90 Percent confidence interval - upper                     0.179
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.059       0.059
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q32_1             1.000                               1.379    0.731
#     Q32_4             0.809    0.080   10.125    0.000    1.116    0.711
#     Q32_5             1.038    0.078   13.312    0.000    1.432    0.869
#   Affect =~
#     Q32_7             1.000                               1.429    0.753
#     Q32_11            0.951    0.050   18.848    0.000    1.359    0.870
#     Q32_14            0.846    0.058   14.529    0.000    1.209    0.799
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            1.459    0.193    7.543    0.000    0.741    0.741
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q32_1             1.659    0.205    8.109    0.000    1.659    0.466
#    .Q32_4             1.219    0.147    8.319    0.000    1.219    0.495
#    .Q32_5             0.665    0.149    4.472    0.000    0.665    0.245
#    .Q32_7             1.555    0.178    8.754    0.000    1.555    0.432
#    .Q32_11            0.596    0.114    5.229    0.000    0.596    0.244
#    .Q32_14            0.829    0.113    7.365    0.000    0.829    0.362
#     Cognition         1.902    0.238    8.001    0.000    1.000    1.000
#     Affect            2.041    0.222    9.209    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q32_1             0.534
#     Q32_4             0.505
#     Q32_5             0.755
#     Q32_7             0.568
#     Q32_11            0.756
#     Q32_14            0.638

# %%
resid(premathfit)
# Out:
# $type
# [1] "raw"
#
# $cov
#        Q32_1  Q32_4  Q32_5  Q32_7  Q32_11 Q32_14
# Q32_1   0.000
# Q32_4  -0.015  0.000
# Q32_5  -0.111  0.106  0.000
# Q32_7   0.413 -0.299 -0.022  0.000
# Q32_11  0.117 -0.286 -0.066  0.072  0.000
# Q32_14  0.440 -0.123  0.100 -0.115  0.001  0.000

# %%
alpha(MathAttPreSubset[c('Q32_1', 'Q32_4', 'Q32_5')])
# Out:
# Reliability analysis
# Call: alpha(x = MathAttPreSubset[c("Q32_1", "Q32_4", "Q32_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.81      0.81    0.75      0.59 4.3 0.017  3.3 1.5      0.6
#
#  lower alpha upper     95% confidence boundaries
# 0.77 0.81 0.84
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q32_1      0.79      0.79    0.66      0.66 3.9    0.021    NA  0.66
# Q32_4      0.75      0.75    0.60      0.60 3.0    0.025    NA  0.60
# Q32_5      0.67      0.68    0.51      0.51 2.1    0.033    NA  0.51
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q32_1 389  0.85  0.83  0.68   0.61  3.5 1.9
# Q32_4 389  0.83  0.85  0.74   0.65  2.9 1.6
# Q32_5 389  0.88  0.88  0.81   0.72  3.4 1.6
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q32_1 0.18 0.17 0.21 0.12 0.13 0.11 0.08    0
# Q32_4 0.20 0.26 0.23 0.15 0.08 0.05 0.03    0
# Q32_5 0.11 0.21 0.25 0.16 0.12 0.10 0.05    0

# %%
alpha(MathAttPreSubset[c('Q32_7', 'Q32_11', 'Q32_14')])
# Out:
# Reliability analysis
# Call: alpha(x = MathAttPreSubset[c("Q32_7", "Q32_11", "Q32_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.84      0.85    0.79      0.65 5.5 0.014  4.4 1.4     0.68
#
#  lower alpha upper     95% confidence boundaries
# 0.81 0.84 0.87
#
#  Reliability if an item is dropped:
#        raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q32_7       0.82      0.82    0.70      0.70 4.6    0.018    NA  0.70
# Q32_11      0.71      0.72    0.56      0.56 2.6    0.029    NA  0.56
# Q32_14      0.80      0.81    0.68      0.68 4.2    0.020    NA  0.68
#
#  Item statistics
#          n raw.r std.r r.cor r.drop mean  sd
# Q32_7  389  0.88  0.85  0.74   0.67  4.5 1.9
# Q32_11 389  0.90  0.91  0.85   0.78  4.4 1.6
# Q32_14 389  0.84  0.86  0.75   0.68  4.3 1.5
#
# Non missing response frequency for each item
#           1    2    3    4    5    6    7 miss
# Q32_7  0.08 0.10 0.12 0.17 0.16 0.17 0.20    0
# Q32_11 0.04 0.07 0.14 0.31 0.20 0.11 0.13    0
# Q32_14 0.04 0.08 0.16 0.30 0.21 0.11 0.10    0

# %%
MathAttPostSubset<-PostSurveyChemData[-1,c('Q32_1', 'Q32_4', 'Q32_5', 'Q32_7', 'Q32_11', 'Q32_14')]
MathAttPostSubset<-na.omit(MathAttPostSubset)
MathAttPostSubset<-as.data.frame(sapply(MathAttPostSubset,as.numeric))

# %%
MathAttPostSubset["Q32_1"]<-(MathAttPostSubset["Q32_1"] - 8)*-1
MathAttPostSubset["Q32_7"]<-(MathAttPostSubset["Q32_7"] - 8)*-1
MathAttPostSubset["Q32_11"]<-(MathAttPostSubset["Q32_11"] - 8)*-1
MathAttPostSubset["Q32_14"]<-(MathAttPostSubset["Q32_14"] - 8)*-1

# %%
postmathfit.model<-'Cognition =~ Q32_1 + Q32_4 + Q32_5
                Affect =~ Q32_7 + Q32_11 + Q32_14'

# %%
postmathfit <- cfa(postmathfit.model, data=MathAttPostSubset, estimator="MLR")

# %%
summary(postmathfit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 30 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           203
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 19.293      15.062
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.013       0.058
#   Scaling correction factor                                   1.281
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                               699.058     457.343
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.529
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.983       0.984
#   Tucker-Lewis Index (TLI)                       0.969       0.970
#
#   Robust Comparative Fit Index (CFI)                         0.987
#   Robust Tucker-Lewis Index (TLI)                            0.975
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -2071.850   -2071.850
#   Scaling correction factor                                  1.292
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -2062.204   -2062.204
#   Scaling correction factor                                  1.288
#       for the MLR correction
#
#   Akaike (AIC)                                4169.701    4169.701
#   Bayesian (BIC)                              4212.772    4212.772
#   Sample-size adjusted Bayesian (BIC)         4171.585    4171.585
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.083       0.066
#   90 Percent confidence interval - lower         0.036       0.013
#   90 Percent confidence interval - upper         0.132       0.111
#   P-value RMSEA <= 0.05                          0.109       0.247
#
#   Robust RMSEA                                               0.075
#   90 Percent confidence interval - lower                        NA
#   90 Percent confidence interval - upper                     0.132
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.033       0.033
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q32_1             1.000                               1.536    0.805
#     Q32_4             0.794    0.069   11.523    0.000    1.218    0.756
#     Q32_5             0.985    0.053   18.556    0.000    1.513    0.867
#   Affect =~
#     Q32_7             1.000                               1.538    0.766
#     Q32_11            0.903    0.070   12.834    0.000    1.389    0.845
#     Q32_14            0.894    0.090    9.946    0.000    1.376    0.842
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            1.911    0.249    7.684    0.000    0.809    0.809
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q32_1             1.285    0.185    6.949    0.000    1.285    0.353
#    .Q32_4             1.116    0.175    6.373    0.000    1.116    0.429
#    .Q32_5             0.754    0.194    3.894    0.000    0.754    0.248
#    .Q32_7             1.667    0.329    5.063    0.000    1.667    0.413
#    .Q32_11            0.776    0.152    5.110    0.000    0.776    0.287
#    .Q32_14            0.780    0.171    4.569    0.000    0.780    0.292
#     Cognition         2.358    0.275    8.572    0.000    1.000    1.000
#     Affect            2.366    0.375    6.307    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q32_1             0.647
#     Q32_4             0.571
#     Q32_5             0.752
#     Q32_7             0.587
#     Q32_11            0.713
#     Q32_14            0.708

# %%
describe(MathAttPostSubset)
# Out:
#        vars n   mean     sd       median trimmed  mad    min max range
# Q32_1  1    203 3.418719 1.913228 3      3.325153 2.9652 1   7   6
# Q32_4  2    203 2.901478 1.616789 3      2.717791 1.4826 1   7   6
# Q32_5  3    203 3.423645 1.748502 3      3.319018 1.4826 1   7   6
# Q32_7  4    203 4.256158 2.013174 4      4.319018 2.9652 1   7   6
# Q32_11 5    203 4.241379 1.648841 4      4.276074 1.4826 1   7   6
# Q32_14 6    203 4.113300 1.638633 4      4.141104 1.4826 1   7   6
#        skew       kurtosis   se
# Q32_1   0.3075862 -1.1725692 0.1342823
# Q32_4   0.8162143  0.1195833 0.1134764
# Q32_5   0.4199167 -0.7536460 0.1227208
# Q32_7  -0.2164731 -1.1717445 0.1412971
# Q32_11 -0.1225647 -0.5233383 0.1157259
# Q32_14 -0.1541179 -0.3998571 0.1150095

# %%
alpha(MathAttPostSubset[c('Q32_1', 'Q32_4', 'Q32_5')])
# Out:
# Reliability analysis
# Call: alpha(x = MathAttPostSubset[c("Q32_1", "Q32_4", "Q32_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.85      0.85    0.79      0.66 5.7 0.018  3.2 1.5     0.68
#
#  lower alpha upper     95% confidence boundaries
# 0.81 0.85 0.88
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q32_1      0.81      0.81    0.68      0.68 4.2    0.027    NA  0.68
# Q32_4      0.80      0.81    0.68      0.68 4.2    0.027    NA  0.68
# Q32_5      0.76      0.76    0.62      0.62 3.2    0.034    NA  0.62
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q32_1 203  0.88  0.87  0.76   0.71  3.4 1.9
# Q32_4 203  0.86  0.87  0.77   0.70  2.9 1.6
# Q32_5 203  0.89  0.89  0.82   0.75  3.4 1.7
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q32_1 0.21 0.18 0.18 0.11 0.13 0.14 0.06    0
# Q32_4 0.22 0.23 0.25 0.14 0.07 0.03 0.05    0
# Q32_5 0.14 0.21 0.21 0.16 0.14 0.07 0.07    0

# %%
alpha(MathAttPostSubset[c('Q32_7', 'Q32_11', 'Q32_14')])
# Out:
# Reliability analysis
# Call: alpha(x = MathAttPostSubset[c("Q32_7", "Q32_11", "Q32_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.85      0.86    0.81      0.67 6.1 0.018  4.2 1.6     0.69
#
#  lower alpha upper     95% confidence boundaries
# 0.82 0.85 0.89
#
#  Reliability if an item is dropped:
#        raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q32_7       0.83      0.83    0.70      0.70 4.7    0.025    NA  0.70
# Q32_11      0.75      0.76    0.62      0.62 3.2    0.034    NA  0.62
# Q32_14      0.81      0.82    0.69      0.69 4.4    0.026    NA  0.69
#
#  Item statistics
#          n raw.r std.r r.cor r.drop mean  sd
# Q32_7  203  0.89  0.87  0.76   0.71  4.3 2.0
# Q32_11 203  0.89  0.90  0.84   0.77  4.2 1.6
# Q32_14 203  0.86  0.88  0.78   0.71  4.1 1.6
#
# Non missing response frequency for each item
#           1    2    3    4    5    6    7 miss
# Q32_7  0.14 0.11 0.08 0.18 0.17 0.14 0.18    0
# Q32_11 0.08 0.06 0.15 0.31 0.17 0.12 0.11    0
# Q32_14 0.10 0.06 0.12 0.33 0.20 0.08 0.10    0
