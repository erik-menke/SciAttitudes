# %%
library(lavaan)
library(readxl)
library(psych)
# Out:
# This is lavaan 0.6-6
# lavaan is BETA software! Please report any bugs.
#
# Attaching package: ‘psych’
#
# The following object is masked from ‘package:lavaan’:
#
#     cor2cov

# %%
path = "/Users/erikmenke/UC-Merced/Data/2018-2019/NSF HSI/2018-2019StudentData/2019Spring/Survey/"
PreSurveyChemDataFilename = "Presurvey.xlsx"
PostSurveyChemDataFilename = "Postsurvey.xlsx"

PreSurveyChemData <- read_excel(paste(path, PreSurveyChemDataFilename, sep=""))
PostSurveyChemData <- read_excel(paste(path, PostSurveyChemDataFilename, sep=""))
# Out:
# New names:
# * Q35 -> Q35...1
# * Q35 -> Q35...96
# New names:
# * Q35 -> Q35...1
# * Q35 -> Q35...96

# %%
describe(PreSurveyChemData[-1,c('Q32_1', 'Q32_2', 'Q32_3', 'Q32_4', 'Q32_5',
                                'Q32_6', 'Q32_7', 'Q32_8', 'Q32_9', 'Q32_10',
                                'Q32_11', 'Q32_12', 'Q32_13', 'Q32_14', 'Q32_15',
                                'Q32_16', 'Q32_17', 'Q32_18', 'Q32_19', 'Q32_20'
                               )])
# Out:
#         vars n   mean     sd       median trimmed  mad    min max range
# Q32_1*   1   685 4.557664 1.884444 5      4.686703 1.4826 1   7   6
# Q32_2*   2   685 5.616058 1.556923 6      5.876138 1.4826 1   7   6
# Q32_3*   3   685 3.756204 1.724559 4      3.717668 1.4826 1   7   6
# Q32_4*   4   685 2.929927 1.579583 3      2.765027 1.4826 1   7   6
# Q32_5*   5   685 3.411679 1.637422 3      3.326047 1.4826 1   7   6
# Q32_6*   6   685 2.859854 1.522994 3      2.703097 1.4826 1   7   6
# Q32_7*   7   685 3.543066 1.880175 3      3.440801 1.4826 1   7   6
# Q32_8*   8   685 3.868613 1.678108 4      3.857923 1.4826 1   7   6
# Q32_9*   9   685 3.259854 1.467855 3      3.185792 1.4826 1   7   6
# Q32_10* 10   685 2.402920 1.329377 2      2.238616 1.4826 1   7   6
# Q32_11* 11   685 3.715328 1.610224 4      3.664845 1.4826 1   7   6
# Q32_12* 12   685 3.400000 1.695539 3      3.291439 1.4826 1   7   6
# Q32_13* 13   685 4.183942 1.368411 4      4.218579 1.4826 1   7   6
# Q32_14* 14   685 3.748905 1.511560 4      3.686703 1.4826 1   7   6
# Q32_15* 15   685 2.706569 1.455992 3      2.561020 1.4826 1   7   6
# Q32_16* 16   685 2.334307 1.429863 2      2.142077 1.4826 1   7   6
# Q32_17* 17   685 4.293431 1.812086 4      4.366120 1.4826 1   7   6
# Q32_18* 18   685 2.893431 1.617349 3      2.774135 1.4826 1   7   6
# Q32_19* 19   685 3.293431 1.497571 3      3.233151 1.4826 1   7   6
# Q32_20* 20   685 4.205839 1.541804 4      4.225865 1.4826 1   7   6
#         skew        kurtosis    se
# Q32_1*  -0.41415137 -0.91782708 0.07200090
# Q32_2*  -1.20009709  0.94166296 0.05948699
# Q32_3*   0.14651896 -0.75390804 0.06589200
# Q32_4*   0.73748632 -0.05991606 0.06035277
# Q32_5*   0.36420599 -0.52854091 0.06256267
# Q32_6*   0.74010462  0.29645661 0.05819062
# Q32_7*   0.27826933 -0.97368393 0.07183779
# Q32_8*   0.02927845 -0.62963920 0.06411720
# Q32_9*   0.49903064  0.02269068 0.05608387
# Q32_10*  0.94703240  0.62736204 0.05079288
# Q32_11*  0.25713862 -0.29003402 0.06152348
# Q32_12*  0.38828589 -0.55318339 0.06478323
# Q32_13* -0.14530836  0.57501195 0.05228430
# Q32_14*  0.28240103 -0.14003688 0.05775372
# Q32_15*  0.72399577  0.25736255 0.05563060
# Q32_16*  1.02215892  0.49929062 0.05463226
# Q32_17* -0.22656415 -0.84191412 0.06923625
# Q32_18*  0.36088614 -0.54288013 0.06179575
# Q32_19*  0.23093671 -0.24391868 0.05721926
# Q32_20* -0.11194303 -0.07149608 0.05890929

# %%
MathAttPreSubset<-PreSurveyChemData[-1,c('Q32_1', 'Q32_4', 'Q32_5', 'Q32_7', 'Q32_11', 'Q32_14')]
MathAttPreSubset<-na.omit(MathAttPreSubset)
MathAttPreSubset<-as.data.frame(sapply(MathAttPreSubset,as.numeric))

# %%
MathAttPreSubset["Q32_1"]<-(MathAttPreSubset["Q32_1"] - 8)*-1
MathAttPreSubset["Q32_7"]<-(MathAttPreSubset["Q32_7"] - 8)*-1
MathAttPreSubset["Q32_11"]<-(MathAttPreSubset["Q32_11"] - 8)*-1
MathAttPreSubset["Q32_14"]<-(MathAttPreSubset["Q32_14"] - 8)*-1

# %%
describe(MathAttPreSubset)
# Out:
#        vars n   mean     sd       median trimmed  mad    min max range
# Q32_1  1    685 3.442336 1.884444 3      3.313297 1.4826 1   7   6
# Q32_4  2    685 2.929927 1.579583 3      2.765027 1.4826 1   7   6
# Q32_5  3    685 3.411679 1.637422 3      3.326047 1.4826 1   7   6
# Q32_7  4    685 4.456934 1.880175 5      4.559199 1.4826 1   7   6
# Q32_11 5    685 4.284672 1.610224 4      4.335155 1.4826 1   7   6
# Q32_14 6    685 4.251095 1.511560 4      4.313297 1.4826 1   7   6
#        skew       kurtosis    se
# Q32_1   0.4141514 -0.91782708 0.07200090
# Q32_4   0.7374863 -0.05991606 0.06035277
# Q32_5   0.3642060 -0.52854091 0.06256267
# Q32_7  -0.2782693 -0.97368393 0.07183779
# Q32_11 -0.2571386 -0.29003402 0.06152348
# Q32_14 -0.2824010 -0.14003688 0.05775372

# %%
premathfit.model<-'Cognition =~ Q32_1 + Q32_4 + Q32_5
                Affect =~ Q32_7 + Q32_11 + Q32_14'

# %%
premathfit <- cfa(premathfit.model, data=MathAttPreSubset, estimator="MLR")

# %%
summary(premathfit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 31 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           685
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                113.778      95.765
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.000       0.000
#   Scaling correction factor                                   1.188
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                              2106.025    1357.165
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.552
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.949       0.935
#   Tucker-Lewis Index (TLI)                       0.905       0.877
#
#   Robust Comparative Fit Index (CFI)                         0.950
#   Robust Tucker-Lewis Index (TLI)                            0.906
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -6959.497   -6959.497
#   Scaling correction factor                                  1.411
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -6902.608   -6902.608
#   Scaling correction factor                                  1.326
#       for the MLR correction
#
#   Akaike (AIC)                               13944.994   13944.994
#   Bayesian (BIC)                             14003.877   14003.877
#   Sample-size adjusted Bayesian (BIC)        13962.600   13962.600
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.139       0.127
#   90 Percent confidence interval - lower         0.117       0.106
#   90 Percent confidence interval - upper         0.162       0.148
#   P-value RMSEA <= 0.05                          0.000       0.000
#
#   Robust RMSEA                                               0.138
#   90 Percent confidence interval - lower                     0.114
#   90 Percent confidence interval - upper                     0.163
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.053       0.053
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q32_1             1.000                               1.491    0.792
#     Q32_4             0.796    0.052   15.258    0.000    1.188    0.753
#     Q32_5             0.881    0.052   16.827    0.000    1.314    0.803
#   Affect =~
#     Q32_7             1.000                               1.394    0.742
#     Q32_11            0.959    0.046   21.067    0.000    1.338    0.832
#     Q32_14            0.929    0.053   17.515    0.000    1.296    0.858
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            1.523    0.143   10.652    0.000    0.732    0.732
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q32_1             1.322    0.143    9.227    0.000    1.322    0.373
#    .Q32_4             1.081    0.125    8.646    0.000    1.081    0.434
#    .Q32_5             0.950    0.134    7.090    0.000    0.950    0.355
#    .Q32_7             1.585    0.146   10.875    0.000    1.585    0.449
#    .Q32_11            0.799    0.099    8.056    0.000    0.799    0.309
#    .Q32_14            0.602    0.078    7.694    0.000    0.602    0.264
#     Cognition         2.224    0.179   12.402    0.000    1.000    1.000
#     Affect            1.944    0.181   10.732    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q32_1             0.627
#     Q32_4             0.566
#     Q32_5             0.645
#     Q32_7             0.551
#     Q32_11            0.691
#     Q32_14            0.736

# %%
resid(premathfit)
# Out:
# $type
# [1] "raw"
#
# $cov
#        Q32_1  Q32_4  Q32_5  Q32_7  Q32_11 Q32_14
# Q32_1   0.000
# Q32_4   0.007  0.000
# Q32_5  -0.151  0.149  0.000
# Q32_7   0.228 -0.357 -0.048  0.000
# Q32_11  0.162 -0.345 -0.018  0.085  0.000
# Q32_14  0.279 -0.117  0.049 -0.044 -0.011  0.000

# %%
alpha(MathAttPreSubset[c('Q32_1', 'Q32_4', 'Q32_5')])
# Out:
# Reliability analysis
# Call: alpha(x = MathAttPreSubset[c("Q32_1", "Q32_4", "Q32_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.82      0.83    0.76      0.62 4.8 0.012  3.3 1.5      0.6
#
#  lower alpha upper     95% confidence boundaries
# 0.8 0.82 0.85
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q32_1      0.80      0.80    0.66      0.66 3.9    0.016    NA  0.66
# Q32_4      0.74      0.74    0.59      0.59 2.8    0.020    NA  0.59
# Q32_5      0.74      0.75    0.60      0.60 3.0    0.019    NA  0.60
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q32_1 685  0.86  0.84  0.71   0.65  3.4 1.9
# Q32_4 685  0.86  0.87  0.78   0.70  2.9 1.6
# Q32_5 685  0.86  0.87  0.77   0.69  3.4 1.6
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q32_1 0.18 0.19 0.19 0.15 0.12 0.08 0.09    0
# Q32_4 0.20 0.24 0.25 0.15 0.07 0.05 0.03    0
# Q32_5 0.14 0.16 0.26 0.20 0.12 0.07 0.05    0

# %%
alpha(MathAttPreSubset[c('Q32_7', 'Q32_11', 'Q32_14')])
# Out:
# Reliability analysis
# Call: alpha(x = MathAttPreSubset[c("Q32_7", "Q32_11", "Q32_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N  ase mean  sd median_r
#       0.85      0.85     0.8      0.66 5.8 0.01  4.3 1.5     0.65
#
#  lower alpha upper     95% confidence boundaries
# 0.83 0.85 0.87
#
#  Reliability if an item is dropped:
#        raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q32_7       0.83      0.83    0.71      0.71 4.9    0.013    NA  0.71
# Q32_11      0.76      0.77    0.62      0.62 3.3    0.018    NA  0.62
# Q32_14      0.78      0.78    0.65      0.65 3.6    0.017    NA  0.65
#
#  Item statistics
#          n raw.r std.r r.cor r.drop mean  sd
# Q32_7  685  0.88  0.86  0.74   0.69  4.5 1.9
# Q32_11 685  0.89  0.89  0.82   0.75  4.3 1.6
# Q32_14 685  0.87  0.88  0.80   0.73  4.3 1.5
#
# Non missing response frequency for each item
#           1    2    3    4    5    6    7 miss
# Q32_7  0.09 0.09 0.12 0.20 0.16 0.16 0.18    0
# Q32_11 0.08 0.05 0.11 0.32 0.23 0.10 0.11    0
# Q32_14 0.07 0.05 0.13 0.34 0.21 0.13 0.07    0

# %%
MathAttPostSubset<-PostSurveyChemData[-1,c('Q32_1', 'Q32_4', 'Q32_5', 'Q32_7', 'Q32_11', 'Q32_14')]
MathAttPostSubset<-na.omit(MathAttPostSubset)
MathAttPostSubset<-as.data.frame(sapply(MathAttPostSubset,as.numeric))

# %%
MathAttPostSubset["Q32_1"]<-(MathAttPostSubset["Q32_1"] - 8)*-1
MathAttPostSubset["Q32_7"]<-(MathAttPostSubset["Q32_7"] - 8)*-1
MathAttPostSubset["Q32_11"]<-(MathAttPostSubset["Q32_11"] - 8)*-1
MathAttPostSubset["Q32_14"]<-(MathAttPostSubset["Q32_14"] - 8)*-1

# %%
postmathfit.model<-'Cognition =~ Q32_1 + Q32_4 + Q32_5
                Affect =~ Q32_7 + Q32_11 + Q32_14'

# %%
postmathfit <- cfa(postmathfit.model, data=MathAttPostSubset, estimator="MLR")

# %%
summary(postmathfit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 30 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           174
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 25.021      17.897
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.002       0.022
#   Scaling correction factor                                   1.398
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                               671.919     390.533
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.721
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.974       0.974
#   Tucker-Lewis Index (TLI)                       0.951       0.951
#
#   Robust Comparative Fit Index (CFI)                         0.979
#   Robust Tucker-Lewis Index (TLI)                            0.960
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -1777.737   -1777.737
#   Scaling correction factor                                  1.424
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -1765.227   -1765.227
#   Scaling correction factor                                  1.414
#       for the MLR correction
#
#   Akaike (AIC)                                3581.475    3581.475
#   Bayesian (BIC)                              3622.543    3622.543
#   Sample-size adjusted Bayesian (BIC)         3581.377    3581.377
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.111       0.084
#   90 Percent confidence interval - lower         0.063       0.039
#   90 Percent confidence interval - upper         0.161       0.129
#   P-value RMSEA <= 0.05                          0.021       0.094
#
#   Robust RMSEA                                               0.100
#   90 Percent confidence interval - lower                     0.036
#   90 Percent confidence interval - upper                     0.162
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.038       0.038
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q32_1             1.000                               1.645    0.831
#     Q32_4             0.881    0.056   15.726    0.000    1.450    0.833
#     Q32_5             0.914    0.051   17.772    0.000    1.503    0.854
#   Affect =~
#     Q32_7             1.000                               1.702    0.840
#     Q32_11            0.906    0.059   15.401    0.000    1.542    0.872
#     Q32_14            0.771    0.079    9.754    0.000    1.313    0.811
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            2.107    0.273    7.710    0.000    0.752    0.752
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q32_1             1.217    0.198    6.146    0.000    1.217    0.310
#    .Q32_4             0.931    0.205    4.532    0.000    0.931    0.307
#    .Q32_5             0.839    0.198    4.235    0.000    0.839    0.271
#    .Q32_7             1.211    0.264    4.580    0.000    1.211    0.295
#    .Q32_11            0.749    0.211    3.549    0.000    0.749    0.240
#    .Q32_14            0.897    0.241    3.722    0.000    0.897    0.342
#     Cognition         2.707    0.294    9.197    0.000    1.000    1.000
#     Affect            2.898    0.389    7.457    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q32_1             0.690
#     Q32_4             0.693
#     Q32_5             0.729
#     Q32_7             0.705
#     Q32_11            0.760
#     Q32_14            0.658

# %%
describe(MathAttPostSubset)
# Out:
#        vars n   mean     sd       median trimmed  mad    min max range
# Q32_1  1    174 3.431034 1.986475 3      3.292857 2.9652 1   7   6
# Q32_4  2    174 2.965517 1.746662 3      2.771429 1.4826 1   7   6
# Q32_5  3    174 3.385057 1.765438 3      3.271429 1.4826 1   7   6
# Q32_7  4    174 4.557471 2.032859 5      4.692857 2.9652 1   7   6
# Q32_11 5    174 4.321839 1.773239 4      4.400000 1.4826 1   7   6
# Q32_14 6    174 4.183908 1.623731 4      4.221429 1.4826 1   7   6
#        skew       kurtosis   se
# Q32_1   0.3741335 -1.0851633 0.1505943
# Q32_4   0.7254130 -0.3961263 0.1324141
# Q32_5   0.4054566 -0.7000364 0.1338375
# Q32_7  -0.4438509 -1.0125130 0.1541107
# Q32_11 -0.3226419 -0.6626752 0.1344289
# Q32_14 -0.1916150 -0.5343200 0.1230947

# %%
alpha(MathAttPostSubset[c('Q32_1', 'Q32_4', 'Q32_5')])
# Out:
# Reliability analysis
# Call: alpha(x = MathAttPostSubset[c("Q32_1", "Q32_4", "Q32_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.87      0.88    0.83       0.7 7.1 0.016  3.3 1.6      0.7
#
#  lower alpha upper     95% confidence boundaries
# 0.84 0.87 0.91
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q32_1      0.84      0.84    0.73      0.73 5.4    0.024    NA  0.73
# Q32_4      0.81      0.81    0.68      0.68 4.3    0.029    NA  0.68
# Q32_5      0.82      0.82    0.70      0.70 4.7    0.027    NA  0.70
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q32_1 174  0.90  0.89  0.79   0.74  3.4 2.0
# Q32_4 174  0.90  0.90  0.83   0.78  3.0 1.7
# Q32_5 174  0.89  0.90  0.82   0.76  3.4 1.8
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q32_1 0.22 0.17 0.17 0.13 0.12 0.09 0.10    0
# Q32_4 0.24 0.24 0.18 0.16 0.07 0.06 0.05    0
# Q32_5 0.18 0.16 0.23 0.19 0.10 0.07 0.07    0

# %%
alpha(MathAttPostSubset[c('Q32_7', 'Q32_11', 'Q32_14')])
# Out:
# Reliability analysis
# Call: alpha(x = MathAttPostSubset[c("Q32_7", "Q32_11", "Q32_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.87      0.88    0.83      0.71 7.2 0.016  4.4 1.6     0.69
#
#  lower alpha upper     95% confidence boundaries
# 0.84 0.87 0.91
#
#  Reliability if an item is dropped:
#        raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q32_7       0.81      0.82    0.69      0.69 4.4    0.028    NA  0.69
# Q32_11      0.80      0.81    0.68      0.68 4.2    0.030    NA  0.68
# Q32_14      0.85      0.86    0.75      0.75 6.0    0.022    NA  0.75
#
#  Item statistics
#          n raw.r std.r r.cor r.drop mean  sd
# Q32_7  174  0.92  0.90  0.83   0.78  4.6 2.0
# Q32_11 174  0.91  0.91  0.84   0.79  4.3 1.8
# Q32_14 174  0.87  0.88  0.78   0.73  4.2 1.6
#
# Non missing response frequency for each item
#           1    2    3    4    5    6    7 miss
# Q32_7  0.14 0.06 0.09 0.14 0.19 0.15 0.23    0
# Q32_11 0.11 0.03 0.14 0.24 0.21 0.14 0.13    0
# Q32_14 0.08 0.07 0.14 0.28 0.21 0.13 0.09    0
