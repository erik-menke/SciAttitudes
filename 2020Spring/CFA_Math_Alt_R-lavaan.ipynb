# %%
library(lavaan)
library(readxl)
library(psych)
# Out:
# This is lavaan 0.6-6
# lavaan is BETA software! Please report any bugs.
#
# Attaching package: ‘psych’
#
# The following object is masked from ‘package:lavaan’:
#
#     cor2cov

# %%
path = "/Users/erikmenke/UC-Merced/Data/2019-2020/NSF HSI/Spring 2020/Survey/Postterm/"
PreSurveyChemDataFilename = "Chem Attitudes_Pre-Spring 2020.xlsx"
PostSurveyChemDataFilename = "Chem Attitudes_Post-Spring 2020.xlsx"

PreSurveyChemData <- read_excel(paste(path, PreSurveyChemDataFilename, sep=""))
PostSurveyChemData <- read_excel(paste(path, PostSurveyChemDataFilename, sep=""))
# Out:
# New names:
# * Q35 -> Q35...1
# * Q35 -> Q35...96
# New names:
# * `` -> ...1
# * Q35 -> Q35...2
# * Q35 -> Q35...97

# %%
describe(PreSurveyChemData[-1,c('Q32_1', 'Q32_2', 'Q32_3', 'Q32_4', 'Q32_5',
                                'Q32_6', 'Q32_7', 'Q32_8', 'Q32_9', 'Q32_10',
                                'Q32_11', 'Q32_12', 'Q32_13', 'Q32_14', 'Q32_15',
                                'Q32_16', 'Q32_17', 'Q32_18', 'Q32_19', 'Q32_20'
                               )])
# Out:
#         vars n   mean     sd       median trimmed  mad    min max range
# Q32_1*   1   305 4.626230 1.880816 5      4.726531 2.9652 1   7   6
# Q32_2*   2   305 5.760656 1.427558 6      5.971429 1.4826 1   7   6
# Q32_3*   3   305 3.806557 1.746789 4      3.787755 1.4826 1   7   6
# Q32_4*   4   305 2.767213 1.480656 3      2.604082 1.4826 1   7   6
# Q32_5*   5   305 3.314754 1.593349 3      3.228571 1.4826 1   7   6
# Q32_6*   6   305 2.701639 1.462074 3      2.567347 1.4826 1   7   6
# Q32_7*   7   305 3.537705 1.920986 3      3.428571 1.4826 1   7   6
# Q32_8*   8   305 3.895082 1.624891 4      3.910204 1.4826 1   7   6
# Q32_9*   9   305 3.183607 1.464175 3      3.106122 1.4826 1   7   6
# Q32_10* 10   305 2.304918 1.283297 2      2.155102 1.4826 1   7   6
# Q32_11* 11   305 3.632787 1.569521 4      3.604082 1.4826 1   7   6
# Q32_12* 12   305 3.311475 1.637763 3      3.200000 1.4826 1   7   6
# Q32_13* 13   305 4.288525 1.257360 4      4.285714 1.4826 1   7   6
# Q32_14* 14   305 3.721311 1.454701 4      3.710204 1.4826 1   7   6
# Q32_15* 15   305 2.544262 1.397428 2      2.412245 1.4826 1   7   6
# Q32_16* 16   305 2.291803 1.380110 2      2.126531 1.4826 1   7   6
# Q32_17* 17   305 4.226230 1.820380 4      4.277551 1.4826 1   7   6
# Q32_18* 18   305 2.796721 1.540460 3      2.681633 1.4826 1   7   6
# Q32_19* 19   305 3.160656 1.456754 3      3.114286 1.4826 1   7   6
# Q32_20* 20   305 4.209836 1.513721 4      4.244898 1.4826 1   7   6
#         skew         kurtosis    se
# Q32_1*  -0.338165150 -1.10393373 0.10769519
# Q32_2*  -1.239660604  1.39090428 0.08174171
# Q32_3*   0.048911724 -0.86597779 0.10002086
# Q32_4*   0.844679692  0.21439398 0.08478212
# Q32_5*   0.354786172 -0.58007275 0.09123491
# Q32_6*   0.649112891  0.07230429 0.08371814
# Q32_7*   0.307557577 -1.06319102 0.10999531
# Q32_8*  -0.019115590 -0.60204299 0.09304101
# Q32_9*   0.464954837 -0.24423037 0.08383843
# Q32_10*  0.984178924  0.91846056 0.07348136
# Q32_11*  0.144237119 -0.50577690 0.08987049
# Q32_12*  0.408886504 -0.42022160 0.09377806
# Q32_13* -0.008789488  0.67559272 0.07199621
# Q32_14*  0.105923765 -0.12097996 0.08329596
# Q32_15*  0.763555952  0.29684759 0.08001648
# Q32_16*  0.966050329  0.53808926 0.07902484
# Q32_17* -0.107744601 -0.92065937 0.10423466
# Q32_18*  0.373559537 -0.66332437 0.08820646
# Q32_19*  0.198120721 -0.36970053 0.08341347
# Q32_20* -0.169503681 -0.14245670 0.08667539

# %%
MathAttPreSubset<-PreSurveyChemData[-1,c('Q32_1', 'Q32_4', 'Q32_5', 'Q32_7', 'Q32_11', 'Q32_14')]
MathAttPreSubset<-na.omit(MathAttPreSubset)
MathAttPreSubset<-as.data.frame(sapply(MathAttPreSubset,as.numeric))

# %%
MathAttPreSubset["Q32_1"]<-(MathAttPreSubset["Q32_1"] - 8)*-1
MathAttPreSubset["Q32_7"]<-(MathAttPreSubset["Q32_7"] - 8)*-1
MathAttPreSubset["Q32_11"]<-(MathAttPreSubset["Q32_11"] - 8)*-1
MathAttPreSubset["Q32_14"]<-(MathAttPreSubset["Q32_14"] - 8)*-1

# %%
describe(MathAttPreSubset)
# Out:
#        vars n   mean     sd       median trimmed  mad    min max range
# Q32_1  1    305 3.373770 1.880816 3      3.273469 2.9652 1   7   6
# Q32_4  2    305 2.767213 1.480656 3      2.604082 1.4826 1   7   6
# Q32_5  3    305 3.314754 1.593349 3      3.228571 1.4826 1   7   6
# Q32_7  4    305 4.462295 1.920986 5      4.571429 1.4826 1   7   6
# Q32_11 5    305 4.367213 1.569521 4      4.395918 1.4826 1   7   6
# Q32_14 6    305 4.278689 1.454701 4      4.289796 1.4826 1   7   6
#        skew       kurtosis   se
# Q32_1   0.3381651 -1.1039337 0.10769519
# Q32_4   0.8446797  0.2143940 0.08478212
# Q32_5   0.3547862 -0.5800728 0.09123491
# Q32_7  -0.3075576 -1.0631910 0.10999531
# Q32_11 -0.1442371 -0.5057769 0.08987049
# Q32_14 -0.1059238 -0.1209800 0.08329596

# %%
premathfit.model<-'Cognition =~ Q32_1 + Q32_4 + Q32_5
                Affect =~ Q32_7 + Q32_11 + Q32_14'

# %%
premathfit <- cfa(premathfit.model, data=MathAttPreSubset, estimator="MLR")

# %%
summary(premathfit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 32 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           305
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 44.997      38.527
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.000       0.000
#   Scaling correction factor                                   1.168
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                               918.196     643.113
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.428
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.959       0.951
#   Tucker-Lewis Index (TLI)                       0.923       0.909
#
#   Robust Comparative Fit Index (CFI)                         0.960
#   Robust Tucker-Lewis Index (TLI)                            0.925
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -3062.427   -3062.427
#   Scaling correction factor                                  1.272
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -3039.928   -3039.928
#   Scaling correction factor                                  1.233
#       for the MLR correction
#
#   Akaike (AIC)                                6150.854    6150.854
#   Bayesian (BIC)                              6199.218    6199.218
#   Sample-size adjusted Bayesian (BIC)         6157.988    6157.988
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.123       0.112
#   90 Percent confidence interval - lower         0.090       0.080
#   90 Percent confidence interval - upper         0.159       0.146
#   P-value RMSEA <= 0.05                          0.000       0.001
#
#   Robust RMSEA                                               0.121
#   90 Percent confidence interval - lower                     0.084
#   90 Percent confidence interval - upper                     0.160
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.057       0.057
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q32_1             1.000                               1.347    0.718
#     Q32_4             0.875    0.070   12.584    0.000    1.179    0.797
#     Q32_5             1.010    0.088   11.501    0.000    1.361    0.856
#   Affect =~
#     Q32_7             1.000                               1.524    0.795
#     Q32_11            0.906    0.045   20.129    0.000    1.381    0.881
#     Q32_14            0.702    0.061   11.501    0.000    1.069    0.736
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            1.390    0.192    7.258    0.000    0.677    0.677
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q32_1             1.711    0.204    8.369    0.000    1.711    0.485
#    .Q32_4             0.796    0.124    6.414    0.000    0.796    0.364
#    .Q32_5             0.677    0.131    5.166    0.000    0.677    0.267
#    .Q32_7             1.356    0.180    7.554    0.000    1.356    0.369
#    .Q32_11            0.549    0.123    4.458    0.000    0.549    0.223
#    .Q32_14            0.966    0.147    6.549    0.000    0.966    0.458
#     Cognition         1.815    0.253    7.164    0.000    1.000    1.000
#     Affect            2.322    0.244    9.524    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q32_1             0.515
#     Q32_4             0.636
#     Q32_5             0.733
#     Q32_7             0.631
#     Q32_11            0.777
#     Q32_14            0.542

# %%
resid(premathfit)
# Out:
# $type
# [1] "raw"
#
# $cov
#        Q32_1  Q32_4  Q32_5  Q32_7  Q32_11 Q32_14
# Q32_1   0.000
# Q32_4   0.053  0.000
# Q32_5  -0.100  0.032  0.000
# Q32_7   0.043 -0.296 -0.124  0.000
# Q32_11  0.098 -0.181  0.008  0.070  0.000
# Q32_14  0.458  0.080  0.290 -0.060 -0.045  0.000

# %%
alpha(MathAttPreSubset[c('Q32_1', 'Q32_4', 'Q32_5')])
# Out:
# Reliability analysis
# Call: alpha(x = MathAttPreSubset[c("Q32_1", "Q32_4", "Q32_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.82      0.83    0.77      0.62   5 0.018  3.2 1.4     0.59
#
#  lower alpha upper     95% confidence boundaries
# 0.79 0.82 0.86
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q32_1      0.82      0.82    0.70      0.70 4.6    0.021    NA  0.70
# Q32_4      0.73      0.73    0.58      0.58 2.8    0.030    NA  0.58
# Q32_5      0.73      0.74    0.59      0.59 2.9    0.030    NA  0.59
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q32_1 305  0.86  0.84  0.69   0.64  3.4 1.9
# Q32_4 305  0.86  0.88  0.80   0.72  2.8 1.5
# Q32_5 305  0.87  0.88  0.79   0.71  3.3 1.6
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q32_1 0.21 0.19 0.18 0.11 0.13 0.12 0.06    0
# Q32_4 0.21 0.28 0.26 0.11 0.07 0.05 0.02    0
# Q32_5 0.15 0.18 0.25 0.20 0.12 0.07 0.03    0

# %%
alpha(MathAttPreSubset[c('Q32_7', 'Q32_11', 'Q32_14')])
# Out:
# Reliability analysis
# Call: alpha(x = MathAttPreSubset[c("Q32_7", "Q32_11", "Q32_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.84      0.84    0.79      0.64 5.3 0.016  4.4 1.4     0.63
#
#  lower alpha upper     95% confidence boundaries
# 0.8 0.84 0.87
#
#  Reliability if an item is dropped:
#        raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q32_7       0.77      0.77    0.63      0.63 3.4    0.026    NA  0.63
# Q32_11      0.70      0.72    0.56      0.56 2.6    0.032    NA  0.56
# Q32_14      0.83      0.84    0.72      0.72 5.2    0.019    NA  0.72
#
#  Item statistics
#          n raw.r std.r r.cor r.drop mean  sd
# Q32_7  305  0.90  0.87  0.79   0.72  4.5 1.9
# Q32_11 305  0.90  0.90  0.84   0.77  4.4 1.6
# Q32_14 305  0.82  0.84  0.69   0.64  4.3 1.5
#
# Non missing response frequency for each item
#           1    2    3    4    5    6    7 miss
# Q32_7  0.10 0.10 0.12 0.16 0.16 0.18 0.18    0
# Q32_11 0.05 0.07 0.14 0.30 0.18 0.15 0.10    0
# Q32_14 0.04 0.07 0.13 0.33 0.25 0.09 0.09    0

# %%
MathAttPostSubset<-PostSurveyChemData[-1,c('Q32_1', 'Q32_4', 'Q32_5', 'Q32_7', 'Q32_11', 'Q32_14')]
MathAttPostSubset<-na.omit(MathAttPostSubset)
MathAttPostSubset<-as.data.frame(sapply(MathAttPostSubset,as.numeric))

# %%
MathAttPostSubset["Q32_1"]<-(MathAttPostSubset["Q32_1"] - 8)*-1
MathAttPostSubset["Q32_7"]<-(MathAttPostSubset["Q32_7"] - 8)*-1
MathAttPostSubset["Q32_11"]<-(MathAttPostSubset["Q32_11"] - 8)*-1
MathAttPostSubset["Q32_14"]<-(MathAttPostSubset["Q32_14"] - 8)*-1

# %%
postmathfit.model<-'Cognition =~ Q32_1 + Q32_4 + Q32_5
                Affect =~ Q32_7 + Q32_11 + Q32_14'

# %%
postmathfit <- cfa(postmathfit.model, data=MathAttPostSubset, estimator="MLR")

# %%
summary(postmathfit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 31 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           111
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 19.948      16.704
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.011       0.033
#   Scaling correction factor                                   1.194
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                               396.897     273.042
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.454
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.969       0.966
#   Tucker-Lewis Index (TLI)                       0.941       0.937
#
#   Robust Comparative Fit Index (CFI)                         0.972
#   Robust Tucker-Lewis Index (TLI)                            0.948
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -1065.934   -1065.934
#   Scaling correction factor                                  1.324
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -1055.960   -1055.960
#   Scaling correction factor                                  1.274
#       for the MLR correction
#
#   Akaike (AIC)                                2157.868    2157.868
#   Bayesian (BIC)                              2193.092    2193.092
#   Sample-size adjusted Bayesian (BIC)         2152.009    2152.009
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.116       0.099
#   90 Percent confidence interval - lower         0.053       0.034
#   90 Percent confidence interval - upper         0.181       0.160
#   P-value RMSEA <= 0.05                          0.045       0.090
#
#   Robust RMSEA                                               0.108
#   90 Percent confidence interval - lower                     0.029
#   90 Percent confidence interval - upper                     0.181
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.049       0.049
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q32_1             1.000                               1.444    0.815
#     Q32_4             0.627    0.099    6.301    0.000    0.905    0.655
#     Q32_5             1.011    0.081   12.540    0.000    1.460    0.917
#   Affect =~
#     Q32_7             1.000                               1.428    0.779
#     Q32_11            0.916    0.100    9.129    0.000    1.309    0.854
#     Q32_14            0.875    0.103    8.532    0.000    1.250    0.844
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            1.631    0.312    5.224    0.000    0.790    0.790
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q32_1             1.052    0.230    4.563    0.000    1.052    0.335
#    .Q32_4             1.093    0.219    4.992    0.000    1.093    0.571
#    .Q32_5             0.405    0.143    2.839    0.005    0.405    0.160
#    .Q32_7             1.321    0.304    4.347    0.000    1.321    0.393
#    .Q32_11            0.635    0.235    2.704    0.007    0.635    0.270
#    .Q32_14            0.631    0.161    3.914    0.000    0.631    0.287
#     Cognition         2.087    0.308    6.764    0.000    1.000    1.000
#     Affect            2.040    0.415    4.921    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q32_1             0.665
#     Q32_4             0.429
#     Q32_5             0.840
#     Q32_7             0.607
#     Q32_11            0.730
#     Q32_14            0.713

# %%
describe(MathAttPostSubset)
# Out:
#        vars n   mean     sd       median trimmed  mad    min max range
# Q32_1  1    111 3.387387 1.779536 3      3.292135 1.4826 1   7   6
# Q32_4  2    111 2.675676 1.389324 3      2.528090 1.4826 1   7   6
# Q32_5  3    111 3.306306 1.599959 3      3.202247 1.4826 1   7   6
# Q32_7  4    111 4.423423 1.841687 4      4.528090 1.4826 1   7   6
# Q32_11 5    111 4.603604 1.539063 4      4.640449 1.4826 1   7   6
# Q32_14 6    111 4.360360 1.488091 4      4.370787 1.4826 1   7   6
#        skew        kurtosis   se
# Q32_1   0.35125281 -0.9334279 0.1689061
# Q32_4   0.72688977  0.2437231 0.1318688
# Q32_5   0.46204561 -0.3505539 0.1518614
# Q32_7  -0.27310229 -0.8129719 0.1748052
# Q32_11 -0.12660667 -0.3083221 0.1460814
# Q32_14 -0.05066029 -0.2055150 0.1412433

# %%
alpha(MathAttPostSubset[c('Q32_1', 'Q32_4', 'Q32_5')])
# Out:
# Reliability analysis
# Call: alpha(x = MathAttPostSubset[c("Q32_1", "Q32_4", "Q32_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.84      0.84    0.79      0.64 5.2 0.026  3.1 1.4     0.62
#
#  lower alpha upper     95% confidence boundaries
# 0.79 0.84 0.89
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q32_1      0.76      0.77    0.62      0.62 3.3    0.044    NA  0.62
# Q32_4      0.84      0.85    0.73      0.73 5.5    0.029    NA  0.73
# Q32_5      0.70      0.71    0.55      0.55 2.5    0.055    NA  0.55
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q32_1 111  0.89  0.88  0.79   0.72  3.4 1.8
# Q32_4 111  0.81  0.83  0.68   0.63  2.7 1.4
# Q32_5 111  0.91  0.90  0.85   0.78  3.3 1.6
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q32_1 0.17 0.19 0.22 0.13 0.15 0.09 0.05    0
# Q32_4 0.24 0.22 0.32 0.14 0.04 0.05 0.01    0
# Q32_5 0.15 0.14 0.33 0.16 0.11 0.06 0.05    0

# %%
alpha(MathAttPostSubset[c('Q32_7', 'Q32_11', 'Q32_14')])
# Out:
# Reliability analysis
# Call: alpha(x = MathAttPostSubset[c("Q32_7", "Q32_11", "Q32_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.86      0.86    0.81      0.68 6.3 0.024  4.5 1.4     0.68
#
#  lower alpha upper     95% confidence boundaries
# 0.81 0.86 0.9
#
#  Reliability if an item is dropped:
#        raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q32_7       0.85      0.85    0.74      0.74 5.7    0.028    NA  0.74
# Q32_11      0.75      0.76    0.61      0.61 3.1    0.046    NA  0.61
# Q32_14      0.80      0.81    0.68      0.68 4.2    0.037    NA  0.68
#
#  Item statistics
#          n raw.r std.r r.cor r.drop mean  sd
# Q32_7  111  0.88  0.86  0.74   0.69  4.4 1.8
# Q32_11 111  0.90  0.91  0.86   0.79  4.6 1.5
# Q32_14 111  0.87  0.89  0.80   0.73  4.4 1.5
#
# Non missing response frequency for each item
#           1    2    3    4    5    6    7 miss
# Q32_7  0.10 0.07 0.09 0.26 0.18 0.12 0.18    0
# Q32_11 0.05 0.02 0.13 0.35 0.18 0.12 0.16    0
# Q32_14 0.05 0.05 0.14 0.36 0.19 0.11 0.11    0
