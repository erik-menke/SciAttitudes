# %%
library(lavaan)
library(readxl)
library(psych)
# Out:
# This is lavaan 0.6-6
# lavaan is BETA software! Please report any bugs.
#
# Attaching package: ‘psych’
#
# The following object is masked from ‘package:lavaan’:
#
#     cor2cov

# %%
path = "/Users/erikmenke/UC-Merced/Data/2019-2020/NSF HSI/Spring 2020/Survey/Postterm/"
PreSurveyChemDataFilename = "Chem Attitudes_Pre-Spring 2020.xlsx"
PostSurveyChemDataFilename = "Chem Attitudes_Post-Spring 2020.xlsx"

PreSurveyChemData <- read_excel(paste(path, PreSurveyChemDataFilename, sep=""))
PostSurveyChemData <- read_excel(paste(path, PostSurveyChemDataFilename, sep=""))
# Out:
# New names:
# * Q35 -> Q35...1
# * Q35 -> Q35...96
# New names:
# * `` -> ...1
# * Q35 -> Q35...2
# * Q35 -> Q35...97

# %%
describe(PreSurveyChemData[-1,c('Q1_1', 'Q1_2', 'Q1_3', 'Q1_4', 'Q1_5',
                                'Q1_6', 'Q1_7', 'Q1_8', 'Q1_9', 'Q1_10',
                                'Q1_11', 'Q1_12', 'Q1_13', 'Q1_14', 'Q1_15',
                                'Q1_16', 'Q1_17', 'Q1_18', 'Q1_19', 'Q1_20'
                               )])
# Out:
#        vars n   mean     sd       median trimmed  mad    min max range
# Q1_1*   1   317 4.832808 1.382690 5      4.894118 1.4826 1   7   6
# Q1_2*   2   317 5.769716 1.201514 6      5.901961 1.4826 1   7   6
# Q1_3*   3   317 3.164038 1.424770 3      3.117647 1.4826 1   7   6
# Q1_4*   4   317 2.791798 1.243030 3      2.733333 1.4826 1   7   6
# Q1_5*   5   317 3.343849 1.301801 3      3.345098 1.4826 1   7   6
# Q1_6*   6   317 2.621451 1.360117 2      2.537255 1.4826 1   7   6
# Q1_7*   7   317 3.577287 1.546082 4      3.560784 1.4826 1   7   6
# Q1_8*   8   317 4.179811 1.476344 4      4.207843 1.4826 1   7   6
# Q1_9*   9   317 3.271293 1.235894 3      3.247059 1.4826 1   7   6
# Q1_10* 10   317 2.318612 1.047632 2      2.223529 1.4826 1   6   5
# Q1_11* 11   317 3.482650 1.284221 4      3.490196 1.4826 1   7   6
# Q1_12* 12   317 2.602524 1.342959 2      2.458824 1.4826 1   7   6
# Q1_13* 13   317 4.611987 1.221219 4      4.600000 1.4826 1   7   6
# Q1_14* 14   317 3.760252 1.294804 4      3.752941 1.4826 1   7   6
# Q1_15* 15   317 2.545741 1.209910 2      2.447059 1.4826 1   7   6
# Q1_16* 16   317 2.315457 1.227911 2      2.196078 1.4826 1   7   6
# Q1_17* 17   317 4.561514 1.577182 5      4.623529 1.4826 1   7   6
# Q1_18* 18   317 3.675079 1.397934 4      3.662745 1.4826 1   7   6
# Q1_19* 19   317 3.201893 1.231289 3      3.176471 1.4826 1   7   6
# Q1_20* 20   317 4.230284 1.361995 4      4.247059 1.4826 1   7   6
#        skew        kurtosis    se
# Q1_1*  -0.48747715  0.10549713 0.07765961
# Q1_2*  -0.97111418  1.14602884 0.06748377
# Q1_3*   0.24750757 -0.50949554 0.08002303
# Q1_4*   0.52531011  0.30437164 0.06981549
# Q1_5*   0.08536366 -0.40494473 0.07311641
# Q1_6*   0.45519456 -0.44604041 0.07639178
# Q1_7*   0.05790744 -0.72827821 0.08683660
# Q1_8*  -0.11605035 -0.42474189 0.08291973
# Q1_9*   0.23869035 -0.18740059 0.06941470
# Q1_10*  0.77161017  0.79745266 0.05884086
# Q1_11*  0.06069894  0.03251930 0.07212903
# Q1_12*  0.86415027  0.66468930 0.07542807
# Q1_13* -0.03100472  0.60576312 0.06859047
# Q1_14*  0.05726864  0.29299348 0.07272342
# Q1_15*  0.80169038  0.78564677 0.06795531
# Q1_16*  0.83685416  0.54210625 0.06896638
# Q1_17* -0.27198473 -0.56144880 0.08858334
# Q1_18* -0.02098980 -0.23060277 0.07851578
# Q1_19*  0.34342756  0.41769590 0.06915607
# Q1_20* -0.07471611  0.02768132 0.07649724

# %%
ChemAttPreSubset<-PreSurveyChemData[-1,c('Q1_1', 'Q1_4', 'Q1_5', 'Q1_7', 'Q1_11', 'Q1_14')]
ChemAttPreSubset<-na.omit(ChemAttPreSubset)
ChemAttPreSubset<-as.data.frame(sapply(ChemAttPreSubset,as.numeric))

# %%
ChemAttPreSubset["Q1_1"]<-(ChemAttPreSubset["Q1_1"] - 8)*-1
ChemAttPreSubset["Q1_7"]<-(ChemAttPreSubset["Q1_7"] - 8)*-1
ChemAttPreSubset["Q1_11"]<-(ChemAttPreSubset["Q1_11"] - 8)*-1
ChemAttPreSubset["Q1_14"]<-(ChemAttPreSubset["Q1_14"] - 8)*-1

# %%
describe(ChemAttPreSubset)
# Out:
#       vars n   mean     sd       median trimmed  mad    min max range
# Q1_1  1    317 3.167192 1.382690 3      3.105882 1.4826 1   7   6
# Q1_4  2    317 2.791798 1.243030 3      2.733333 1.4826 1   7   6
# Q1_5  3    317 3.343849 1.301801 3      3.345098 1.4826 1   7   6
# Q1_7  4    317 4.422713 1.546082 4      4.439216 1.4826 1   7   6
# Q1_11 5    317 4.517350 1.284221 4      4.509804 1.4826 1   7   6
# Q1_14 6    317 4.239748 1.294804 4      4.247059 1.4826 1   7   6
#       skew        kurtosis   se
# Q1_1   0.48747715  0.1054971 0.07765961
# Q1_4   0.52531011  0.3043716 0.06981549
# Q1_5   0.08536366 -0.4049447 0.07311641
# Q1_7  -0.05790744 -0.7282782 0.08683660
# Q1_11 -0.06069894  0.0325193 0.07212903
# Q1_14 -0.05726864  0.2929935 0.07272342

# %%
prechemfit.model<-'Cognition =~ Q1_1 + Q1_4 + Q1_5
                Affect =~ Q1_7 + Q1_11 + Q1_14'

#prechemfit.model<-'Cognition =~ Q1_1 + Q1_4 + Q1_5 + Q1_7 + Q1_11 + Q1_14'

# %%
prechemfit <- cfa(prechemfit.model, data=ChemAttPreSubset, estimator="MLR")

# %%
summary(prechemfit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 28 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           317
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 44.642      37.307
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.000       0.000
#   Scaling correction factor                                   1.197
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                               768.851     527.290
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.458
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.951       0.943
#   Tucker-Lewis Index (TLI)                       0.909       0.893
#
#   Robust Comparative Fit Index (CFI)                         0.953
#   Robust Tucker-Lewis Index (TLI)                            0.912
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -2888.324   -2888.324
#   Scaling correction factor                                  1.397
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -2866.003   -2866.003
#   Scaling correction factor                                  1.320
#       for the MLR correction
#
#   Akaike (AIC)                                5802.649    5802.649
#   Bayesian (BIC)                              5851.515    5851.515
#   Sample-size adjusted Bayesian (BIC)         5810.282    5810.282
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.120       0.108
#   90 Percent confidence interval - lower         0.087       0.077
#   90 Percent confidence interval - upper         0.156       0.140
#   P-value RMSEA <= 0.05                          0.000       0.002
#
#   Robust RMSEA                                               0.118
#   90 Percent confidence interval - lower                     0.081
#   90 Percent confidence interval - upper                     0.157
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.064       0.064
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q1_1              1.000                               0.938    0.680
#     Q1_4              1.014    0.118    8.585    0.000    0.951    0.767
#     Q1_5              1.163    0.133    8.770    0.000    1.091    0.840
#   Affect =~
#     Q1_7              1.000                               1.186    0.768
#     Q1_11             0.837    0.071   11.777    0.000    0.993    0.774
#     Q1_14             0.821    0.078   10.534    0.000    0.973    0.753
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            0.702    0.137    5.142    0.000    0.631    0.631
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q1_1              1.026    0.176    5.833    0.000    1.026    0.538
#    .Q1_4              0.635    0.120    5.312    0.000    0.635    0.412
#    .Q1_5              0.499    0.090    5.554    0.000    0.499    0.295
#    .Q1_7              0.977    0.133    7.349    0.000    0.977    0.410
#    .Q1_11             0.658    0.087    7.585    0.000    0.658    0.400
#    .Q1_14             0.724    0.100    7.264    0.000    0.724    0.433
#     Cognition         0.880    0.173    5.095    0.000    1.000    1.000
#     Affect            1.406    0.178    7.880    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q1_1              0.462
#     Q1_4              0.588
#     Q1_5              0.705
#     Q1_7              0.590
#     Q1_11             0.600
#     Q1_14             0.567

# %%
resid(prechemfit)
# Out:
# $type
# [1] "raw"
#
# $cov
#       Q1_1   Q1_4   Q1_5   Q1_7   Q1_11  Q1_14
# Q1_1   0.000
# Q1_4  -0.034  0.000
# Q1_5  -0.062  0.052  0.000
# Q1_7   0.331 -0.135 -0.025  0.000
# Q1_11  0.187 -0.189 -0.098  0.040  0.000
# Q1_14  0.277 -0.014  0.042 -0.050  0.005  0.000

# %%
alpha(ChemAttPreSubset[c('Q1_1', 'Q1_4', 'Q1_5')])
# Out:
# Reliability analysis
# Call: alpha(x = ChemAttPreSubset[c("Q1_1", "Q1_4", "Q1_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N  ase mean  sd median_r
#        0.8       0.8    0.74      0.57   4 0.02  3.1 1.1     0.54
#
#  lower alpha upper     95% confidence boundaries
# 0.76 0.8 0.84
#
#  Reliability if an item is dropped:
#      raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q1_1      0.81      0.81    0.68      0.68 4.2    0.022    NA  0.68
# Q1_4      0.70      0.70    0.54      0.54 2.3    0.034    NA  0.54
# Q1_5      0.66      0.67    0.50      0.50 2.0    0.037    NA  0.50
#
#  Item statistics
#        n raw.r std.r r.cor r.drop mean  sd
# Q1_1 317  0.82  0.80  0.62   0.57  3.2 1.4
# Q1_4 317  0.85  0.86  0.76   0.67  2.8 1.2
# Q1_5 317  0.87  0.87  0.79   0.69  3.3 1.3
#
# Non missing response frequency for each item
#         1    2    3    4    5    6    7 miss
# Q1_1 0.12 0.18 0.34 0.20 0.09 0.04 0.02    0
# Q1_4 0.16 0.25 0.32 0.21 0.03 0.03 0.01    0
# Q1_5 0.09 0.16 0.29 0.28 0.12 0.05 0.00    0

# %%
alpha(ChemAttPreSubset[c('Q1_7', 'Q1_11', 'Q1_14')])
# Out:
# Reliability analysis
# Call: alpha(x = ChemAttPreSubset[c("Q1_7", "Q1_11", "Q1_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#        0.8      0.81    0.74      0.58 4.2 0.019  4.4 1.2     0.59
#
#  lower alpha upper     95% confidence boundaries
# 0.77 0.8 0.84
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q1_7       0.74      0.74    0.59      0.59 2.8    0.029    NA  0.59
# Q1_11      0.71      0.71    0.55      0.55 2.5    0.032    NA  0.55
# Q1_14      0.75      0.76    0.61      0.61 3.2    0.027    NA  0.61
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q1_7  317  0.87  0.85  0.73   0.66  4.4 1.5
# Q1_11 317  0.85  0.86  0.76   0.68  4.5 1.3
# Q1_14 317  0.83  0.84  0.70   0.63  4.2 1.3
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q1_7  0.03 0.07 0.19 0.24 0.19 0.17 0.11    0
# Q1_11 0.02 0.04 0.13 0.34 0.28 0.13 0.08    0
# Q1_14 0.03 0.06 0.14 0.38 0.25 0.08 0.06    0

# %%
ChemAttPostSubset<-PostSurveyChemData[-1,c('Q1_1', 'Q1_4', 'Q1_5', 'Q1_7', 'Q1_11', 'Q1_14')]
ChemAttPostSubset<-na.omit(ChemAttPostSubset)
ChemAttPostSubset<-as.data.frame(sapply(ChemAttPostSubset,as.numeric))

# %%
ChemAttPostSubset["Q1_1"]<-(ChemAttPostSubset["Q1_1"] - 8)*-1
ChemAttPostSubset["Q1_7"]<-(ChemAttPostSubset["Q1_7"] - 8)*-1
ChemAttPostSubset["Q1_11"]<-(ChemAttPostSubset["Q1_11"] - 8)*-1
ChemAttPostSubset["Q1_14"]<-(ChemAttPostSubset["Q1_14"] - 8)*-1

# %%
postchemfit.model<-'Cognition =~ Q1_1 + Q1_4 + Q1_5
                Affect =~ Q1_7 + Q1_11 + Q1_14'

# %%
postchemfit <- cfa(postchemfit.model, data=ChemAttPostSubset, estimator="MLR")

# %%
summary(postchemfit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 31 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           120
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 16.304      13.642
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.038       0.092
#   Scaling correction factor                                   1.195
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                               349.710     269.531
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.297
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.975       0.978
#   Tucker-Lewis Index (TLI)                       0.953       0.958
#
#   Robust Comparative Fit Index (CFI)                         0.980
#   Robust Tucker-Lewis Index (TLI)                            0.962
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -1084.714   -1084.714
#   Scaling correction factor                                  1.208
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -1076.562   -1076.562
#   Scaling correction factor                                  1.203
#       for the MLR correction
#
#   Akaike (AIC)                                2195.428    2195.428
#   Bayesian (BIC)                              2231.665    2231.665
#   Sample-size adjusted Bayesian (BIC)         2190.565    2190.565
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.093       0.077
#   90 Percent confidence interval - lower         0.021       0.000
#   90 Percent confidence interval - upper         0.158       0.139
#   P-value RMSEA <= 0.05                          0.125       0.218
#
#   Robust RMSEA                                               0.084
#   90 Percent confidence interval - lower                     0.000
#   90 Percent confidence interval - upper                     0.158
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.053       0.053
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q1_1              1.000                               1.000    0.672
#     Q1_4              0.797    0.165    4.817    0.000    0.797    0.594
#     Q1_5              1.080    0.206    5.238    0.000    1.080    0.875
#   Affect =~
#     Q1_7              1.000                               1.300    0.797
#     Q1_11             0.919    0.070   13.036    0.000    1.194    0.886
#     Q1_14             0.796    0.086    9.240    0.000    1.034    0.827
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            0.935    0.264    3.548    0.000    0.720    0.720
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q1_1              1.216    0.236    5.158    0.000    1.216    0.549
#    .Q1_4              1.168    0.252    4.633    0.000    1.168    0.648
#    .Q1_5              0.358    0.170    2.114    0.034    0.358    0.235
#    .Q1_7              0.971    0.169    5.757    0.000    0.971    0.365
#    .Q1_11             0.389    0.108    3.594    0.000    0.389    0.214
#    .Q1_14             0.495    0.128    3.865    0.000    0.495    0.317
#     Cognition         1.000    0.296    3.377    0.001    1.000    1.000
#     Affect            1.690    0.282    5.997    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q1_1              0.451
#     Q1_4              0.352
#     Q1_5              0.765
#     Q1_7              0.635
#     Q1_11             0.786
#     Q1_14             0.683

# %%
describe(ChemAttPostSubset)
# Out:
#       vars n   mean     sd       median trimmed  mad    min max range
# Q1_1  1    120 3.366667 1.494715 3.0    3.302083 1.4826 1   7   6
# Q1_4  2    120 3.075000 1.348279 3.0    3.020833 1.4826 1   7   6
# Q1_5  3    120 3.591667 1.240059 4.0    3.583333 1.4826 1   6   5
# Q1_7  4    120 4.425000 1.638110 4.0    4.468750 1.4826 1   7   6
# Q1_11 5    120 4.533333 1.353075 4.0    4.552083 1.4826 1   7   6
# Q1_14 6    120 4.458333 1.256217 4.5    4.520833 0.7413 1   7   6
#       skew        kurtosis    se
# Q1_1   0.39834640 -0.25662121 0.1364482
# Q1_4   0.49733949 -0.07021842 0.1230805
# Q1_5   0.01457371 -0.55411307 0.1132013
# Q1_7  -0.15801632 -0.74937837 0.1495383
# Q1_11 -0.17086013  0.10975204 0.1235183
# Q1_14 -0.54969790  0.83732322 0.1146764

# %%
alpha(ChemAttPostSubset[c('Q1_1', 'Q1_4', 'Q1_5')])
# Out:
# Reliability analysis
# Call: alpha(x = ChemAttPostSubset[c("Q1_1", "Q1_4", "Q1_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.74      0.75    0.68       0.5   3 0.041  3.3 1.1     0.56
#
#  lower alpha upper     95% confidence boundaries
# 0.66 0.74 0.82
#
#  Reliability if an item is dropped:
#      raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q1_1      0.72      0.72    0.56      0.56 2.6    0.051    NA  0.56
# Q1_4      0.71      0.72    0.56      0.56 2.6    0.051    NA  0.56
# Q1_5      0.54      0.54    0.37      0.37 1.2    0.083    NA  0.37
#
#  Item statistics
#        n raw.r std.r r.cor r.drop mean  sd
# Q1_1 120  0.81  0.79  0.62   0.53  3.4 1.5
# Q1_4 120  0.78  0.79  0.62   0.52  3.1 1.3
# Q1_5 120  0.85  0.87  0.78   0.68  3.6 1.2
#
# Non missing response frequency for each item
#         1    2    3    4    5    6    7 miss
# Q1_1 0.12 0.14 0.34 0.18 0.12 0.06 0.03    0
# Q1_4 0.11 0.27 0.27 0.22 0.10 0.02 0.02    0
# Q1_5 0.04 0.15 0.28 0.29 0.17 0.07 0.00    0

# %%
alpha(ChemAttPostSubset[c('Q1_7', 'Q1_11', 'Q1_14')])
# Out:
# Reliability analysis
# Call: alpha(x = ChemAttPostSubset[c("Q1_7", "Q1_11", "Q1_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.87      0.87    0.83       0.7 6.9 0.021  4.5 1.3     0.72
#
#  lower alpha upper     95% confidence boundaries
# 0.82 0.87 0.91
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q1_7       0.85      0.85    0.73      0.73 5.5    0.028    NA  0.73
# Q1_11      0.76      0.78    0.64      0.64 3.5    0.041    NA  0.64
# Q1_14      0.83      0.83    0.72      0.72 5.0    0.031    NA  0.72
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q1_7  120  0.90  0.88  0.78   0.73  4.4 1.6
# Q1_11 120  0.91  0.91  0.86   0.80  4.5 1.4
# Q1_14 120  0.87  0.89  0.80   0.74  4.5 1.3
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q1_7  0.05 0.07 0.17 0.27 0.14 0.19 0.12    0
# Q1_11 0.02 0.05 0.08 0.38 0.24 0.13 0.09    0
# Q1_14 0.04 0.02 0.10 0.34 0.32 0.13 0.04    0
