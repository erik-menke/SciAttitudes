# %%
library(lavaan)
library(readxl)
library(psych)
# Out:
# This is lavaan 0.6-6
# lavaan is BETA software! Please report any bugs.
#
# Attaching package: ‘psych’
#
# The following object is masked from ‘package:lavaan’:
#
#     cor2cov

# %%
path = "/Users/erikmenke/UC-Merced/Data/2019-2020/NSF HSI/Spring 2020/Survey/Postterm/"
PreSurveyChemDataFilename = "Chem Attitudes_Pre-Spring 2020.xlsx"
PostSurveyChemDataFilename = "Chem Attitudes_Post-Spring 2020.xlsx"

PreSurveyChemData <- read_excel(paste(path, PreSurveyChemDataFilename, sep=""))
PostSurveyChemData <- read_excel(paste(path, PostSurveyChemDataFilename, sep=""))
# Out:
# New names:
# * Q35 -> Q35...1
# * Q35 -> Q35...96
# New names:
# * `` -> ...1
# * Q35 -> Q35...2
# * Q35 -> Q35...97

# %%
describe(PreSurveyChemData[-1,c('Q34_1', 'Q34_2', 'Q34_3', 'Q34_4', 'Q34_5',
                                'Q34_6', 'Q34_7', 'Q34_8', 'Q34_9', 'Q34_10',
                                'Q34_11', 'Q34_12', 'Q34_13', 'Q34_14', 'Q34_15',
                                'Q34_16', 'Q34_17', 'Q34_18', 'Q34_19', 'Q34_20'
                               )])
# Out:
#         vars n   mean     sd       median trimmed  mad    min max range
# Q34_1*   1   308 4.097403 1.621394 4      4.108871 1.4826 1   7   6
# Q34_2*   2   308 5.996753 1.228061 6      6.209677 1.4826 1   7   6
# Q34_3*   3   308 2.792208 1.662678 3      2.588710 1.4826 1   7   6
# Q34_4*   4   308 3.272727 1.422356 3      3.229839 1.4826 1   7   6
# Q34_5*   5   308 4.019481 1.466102 4      4.028226 1.4826 1   7   6
# Q34_6*   6   308 2.321429 1.251941 2      2.193548 1.4826 1   7   6
# Q34_7*   7   308 3.003247 1.592937 3      2.870968 1.4826 1   7   6
# Q34_8*   8   308 4.672078 1.427829 5      4.717742 1.4826 1   7   6
# Q34_9*   9   308 2.737013 1.223678 3      2.665323 1.4826 1   7   6
# Q34_10* 10   308 2.766234 1.257122 3      2.681452 1.4826 1   7   6
# Q34_11* 11   308 2.983766 1.254203 3      2.947581 1.4826 1   7   6
# Q34_12* 12   308 2.149351 1.204132 2      1.995968 1.4826 1   7   6
# Q34_13* 13   308 4.896104 1.206221 5      4.870968 1.4826 1   7   6
# Q34_14* 14   308 3.139610 1.235992 3      3.137097 1.4826 1   7   6
# Q34_15* 15   308 2.194805 1.189410 2      2.064516 1.4826 1   7   6
# Q34_16* 16   308 2.678571 1.359223 3      2.588710 1.4826 1   7   6
# Q34_17* 17   308 4.535714 1.514971 4      4.600806 1.4826 1   7   6
# Q34_18* 18   308 2.798701 1.280675 3      2.786290 1.4826 1   7   6
# Q34_19* 19   308 3.762987 1.364628 4      3.733871 1.4826 1   7   6
# Q34_20* 20   308 4.555195 1.291493 4      4.584677 1.4826 1   7   6
#         skew         kurtosis    se
# Q34_1*  -0.079307443 -0.81242125 0.09238749
# Q34_2*  -1.403285351  1.96274218 0.06997524
# Q34_3*   0.771217987 -0.12939652 0.09473989
# Q34_4*   0.374128929 -0.20821265 0.08104627
# Q34_5*  -0.008826301 -0.51290251 0.08353894
# Q34_6*   0.788884989  0.33903374 0.07133597
# Q34_7*   0.495939493 -0.50545861 0.09076602
# Q34_8*  -0.370772161  0.03373472 0.08135813
# Q34_9*   0.551578620  0.29026819 0.06972552
# Q34_10*  0.621312380  0.46512362 0.07163115
# Q34_11*  0.316826643  0.18420183 0.07146486
# Q34_12*  1.018208575  1.12220668 0.06861180
# Q34_13* -0.133996666  0.24982071 0.06873081
# Q34_14*  0.023611182 -0.22267429 0.07042719
# Q34_15*  0.860392195  0.44441560 0.06777292
# Q34_16*  0.375146124 -0.65505152 0.07744892
# Q34_17* -0.325656710 -0.33630485 0.08632349
# Q34_18*  0.127654940 -0.57693667 0.07297323
# Q34_19*  0.078702791 -0.03607337 0.07775688
# Q34_20* -0.157640815  0.21513886 0.07358963

# %%
BioAttPreSubset<-PreSurveyChemData[-1,c('Q34_1', 'Q34_4', 'Q34_5', 'Q34_7', 'Q34_11', 'Q34_14')]
BioAttPreSubset<-na.omit(BioAttPreSubset)
BioAttPreSubset<-as.data.frame(sapply(BioAttPreSubset,as.numeric))

# %%
BioAttPreSubset["Q34_1"]<-(BioAttPreSubset["Q34_1"] - 8)*-1
BioAttPreSubset["Q34_7"]<-(BioAttPreSubset["Q34_7"] - 8)*-1
BioAttPreSubset["Q34_11"]<-(BioAttPreSubset["Q34_11"] - 8)*-1
BioAttPreSubset["Q34_14"]<-(BioAttPreSubset["Q34_14"] - 8)*-1

# %%
describe(BioAttPreSubset)
# Out:
#        vars n   mean     sd       median trimmed  mad    min max range
# Q34_1  1    308 3.902597 1.621394 4      3.891129 1.4826 1   7   6
# Q34_4  2    308 3.272727 1.422356 3      3.229839 1.4826 1   7   6
# Q34_5  3    308 4.019481 1.466102 4      4.028226 1.4826 1   7   6
# Q34_7  4    308 4.996753 1.592937 5      5.129032 1.4826 1   7   6
# Q34_11 5    308 5.016234 1.254203 5      5.052419 1.4826 1   7   6
# Q34_14 6    308 4.860390 1.235992 5      4.862903 1.4826 1   7   6
#        skew         kurtosis   se
# Q34_1   0.079307443 -0.8124213 0.09238749
# Q34_4   0.374128929 -0.2082127 0.08104627
# Q34_5  -0.008826301 -0.5129025 0.08353894
# Q34_7  -0.495939493 -0.5054586 0.09076602
# Q34_11 -0.316826643  0.1842018 0.07146486
# Q34_14 -0.023611182 -0.2226743 0.07042719

# %%
prebiofit.model<-'Cognition =~ Q34_1 + Q34_4 + Q34_5
                Affect =~ Q34_7 + Q34_11 + Q34_14'

# %%
prebiofit <- cfa(prebiofit.model, data=BioAttPreSubset, estimator="MLR")

# %%
summary(prebiofit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 32 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           308
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 57.979      41.817
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.000       0.000
#   Scaling correction factor                                   1.386
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                               694.131     427.799
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.623
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.926       0.918
#   Tucker-Lewis Index (TLI)                       0.862       0.846
#
#   Robust Comparative Fit Index (CFI)                         0.930
#   Robust Tucker-Lewis Index (TLI)                            0.869
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -2954.743   -2954.743
#   Scaling correction factor                                  1.405
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -2925.754   -2925.754
#   Scaling correction factor                                  1.398
#       for the MLR correction
#
#   Akaike (AIC)                                5935.487    5935.487
#   Bayesian (BIC)                              5983.978    5983.978
#   Sample-size adjusted Bayesian (BIC)         5942.748    5942.748
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.142       0.117
#   90 Percent confidence interval - lower         0.109       0.088
#   90 Percent confidence interval - upper         0.178       0.148
#   P-value RMSEA <= 0.05                          0.000       0.000
#
#   Robust RMSEA                                               0.138
#   90 Percent confidence interval - lower                     0.098
#   90 Percent confidence interval - upper                     0.181
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.079       0.079
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q34_1             1.000                               0.998    0.616
#     Q34_4             0.933    0.137    6.815    0.000    0.930    0.655
#     Q34_5             1.237    0.234    5.286    0.000    1.234    0.843
#   Affect =~
#     Q34_7             1.000                               1.331    0.837
#     Q34_11            0.807    0.053   15.086    0.000    1.074    0.858
#     Q34_14            0.621    0.061   10.113    0.000    0.827    0.670
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            0.630    0.148    4.251    0.000    0.474    0.474
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q34_1             1.625    0.243    6.678    0.000    1.625    0.620
#    .Q34_4             1.151    0.134    8.597    0.000    1.151    0.571
#    .Q34_5             0.621    0.250    2.486    0.013    0.621    0.290
#    .Q34_7             0.757    0.120    6.331    0.000    0.757    0.299
#    .Q34_11            0.415    0.094    4.413    0.000    0.415    0.265
#    .Q34_14            0.840    0.106    7.912    0.000    0.840    0.551
#     Cognition         0.995    0.257    3.867    0.000    1.000    1.000
#     Affect            1.772    0.192    9.228    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q34_1             0.380
#     Q34_4             0.429
#     Q34_5             0.710
#     Q34_7             0.701
#     Q34_11            0.735
#     Q34_14            0.449

# %%
resid(prebiofit)
# Out:
# $type
# [1] "raw"
#
# $cov
#        Q34_1  Q34_4  Q34_5  Q34_7  Q34_11 Q34_14
# Q34_1   0.000
# Q34_4   0.047  0.000
# Q34_5  -0.083  0.048  0.000
# Q34_7   0.396 -0.456 -0.009  0.000
# Q34_11  0.198 -0.257 -0.021  0.015  0.000
# Q34_14  0.290 -0.005  0.211 -0.023 -0.012  0.000

# %%
alpha(BioAttPreSubset[c('Q34_1', 'Q34_4', 'Q34_5')])
# Out:
# Reliability analysis
# Call: alpha(x = BioAttPreSubset[c("Q34_1", "Q34_4", "Q34_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.74      0.75    0.67      0.49 2.9 0.026  3.7 1.2     0.48
#
#  lower alpha upper     95% confidence boundaries
# 0.69 0.74 0.79
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q34_1      0.73      0.73    0.58      0.58 2.7    0.031    NA  0.58
# Q34_4      0.65      0.65    0.48      0.48 1.9    0.040    NA  0.48
# Q34_5      0.59      0.60    0.42      0.42 1.5    0.046    NA  0.42
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q34_1 308  0.80  0.78  0.59   0.51  3.9 1.6
# Q34_4 308  0.80  0.82  0.68   0.58  3.3 1.4
# Q34_5 308  0.84  0.84  0.73   0.62  4.0 1.5
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q34_1 0.07 0.13 0.25 0.17 0.21 0.11 0.06    0
# Q34_4 0.11 0.18 0.32 0.20 0.13 0.04 0.02    0
# Q34_5 0.05 0.09 0.23 0.25 0.21 0.12 0.05    0

# %%
alpha(BioAttPreSubset[c('Q34_7', 'Q34_11', 'Q34_14')])
# Out:
# Reliability analysis
# Call: alpha(x = BioAttPreSubset[c("Q34_7", "Q34_11", "Q34_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.82      0.83    0.77      0.61 4.8 0.017    5 1.2     0.57
#
#  lower alpha upper     95% confidence boundaries
# 0.79 0.82 0.85
#
#  Reliability if an item is dropped:
#        raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q34_7       0.72      0.72    0.57      0.57 2.6    0.032    NA  0.57
# Q34_11      0.69      0.71    0.55      0.55 2.4    0.033    NA  0.55
# Q34_14      0.83      0.84    0.73      0.73 5.3    0.019    NA  0.73
#
#  Item statistics
#          n raw.r std.r r.cor r.drop mean  sd
# Q34_7  308  0.90  0.88  0.80   0.72  5.0 1.6
# Q34_11 308  0.88  0.89  0.82   0.74  5.0 1.3
# Q34_14 308  0.80  0.82  0.65   0.60  4.9 1.2
#
# Non missing response frequency for each item
#           1    2    3    4    5    6    7 miss
# Q34_7  0.02 0.06 0.08 0.19 0.22 0.19 0.22    0
# Q34_11 0.01 0.02 0.05 0.25 0.33 0.19 0.14    0
# Q34_14 0.01 0.02 0.08 0.31 0.29 0.17 0.12    0

# %%
BioAttPostSubset<-PostSurveyChemData[-1,c('Q34_1', 'Q34_4', 'Q34_5', 'Q34_7', 'Q34_11', 'Q34_14')]
BioAttPostSubset<-na.omit(BioAttPostSubset)
BioAttPostSubset<-as.data.frame(sapply(BioAttPostSubset,as.numeric))

# %%
BioAttPostSubset["Q34_1"]<-(BioAttPostSubset["Q34_1"] - 8)*-1
BioAttPostSubset["Q34_7"]<-(BioAttPostSubset["Q34_7"] - 8)*-1
BioAttPostSubset["Q34_11"]<-(BioAttPostSubset["Q34_11"] - 8)*-1
BioAttPostSubset["Q34_14"]<-(BioAttPostSubset["Q34_14"] - 8)*-1

# %%
postbiofit.model<-'Cognition =~ Q34_1 + Q34_4 + Q34_5
                Affect =~ Q34_7 + Q34_11 + Q34_14'

# %%
postbiofit <- cfa(postbiofit.model, data=BioAttPostSubset, estimator="MLR")

# %%
summary(postbiofit, fit.measures=TRUE, standardized=TRUE, rsquare=TRUE)
# Out:
# lavaan 0.6-6 ended normally after 31 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         13
#
#   Number of observations                           114
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 37.736      39.123
#   Degrees of freedom                                  8           8
#   P-value (Chi-square)                            0.000       0.000
#   Scaling correction factor                                   0.965
#        Yuan-Bentler correction (Mplus variant)
#
# Model Test Baseline Model:
#
#   Test statistic                               385.173     267.327
#   Degrees of freedom                                15          15
#   P-value                                        0.000       0.000
#   Scaling correction factor                                  1.441
#
# User Model versus Baseline Model:
#
#   Comparative Fit Index (CFI)                    0.920       0.877
#   Tucker-Lewis Index (TLI)                       0.849       0.769
#
#   Robust Comparative Fit Index (CFI)                         0.917
#   Robust Tucker-Lewis Index (TLI)                            0.845
#
# Loglikelihood and Information Criteria:
#
#   Loglikelihood user model (H0)              -1066.577   -1066.577
#   Scaling correction factor                                  1.475
#       for the MLR correction
#   Loglikelihood unrestricted model (H1)      -1047.709   -1047.709
#   Scaling correction factor                                  1.280
#       for the MLR correction
#
#   Akaike (AIC)                                2159.154    2159.154
#   Bayesian (BIC)                              2194.725    2194.725
#   Sample-size adjusted Bayesian (BIC)         2153.636    2153.636
#
# Root Mean Square Error of Approximation:
#
#   RMSEA                                          0.181       0.185
#   90 Percent confidence interval - lower         0.125       0.128
#   90 Percent confidence interval - upper         0.240       0.246
#   P-value RMSEA <= 0.05                          0.000       0.000
#
#   Robust RMSEA                                               0.181
#   90 Percent confidence interval - lower                     0.127
#   90 Percent confidence interval - upper                     0.240
#
# Standardized Root Mean Square Residual:
#
#   SRMR                                           0.080       0.080
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition =~
#     Q34_1             1.000                               1.242    0.776
#     Q34_4             0.944    0.107    8.801    0.000    1.172    0.801
#     Q34_5             1.159    0.139    8.322    0.000    1.439    0.930
#   Affect =~
#     Q34_7             1.000                               1.274    0.812
#     Q34_11            0.910    0.097    9.377    0.000    1.160    0.816
#     Q34_14            0.790    0.118    6.701    0.000    1.007    0.764
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#   Cognition ~~
#     Affect            0.872    0.225    3.884    0.000    0.551    0.551
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)   Std.lv  Std.all
#    .Q34_1             1.021    0.220    4.644    0.000    1.021    0.398
#    .Q34_4             0.768    0.190    4.035    0.000    0.768    0.358
#    .Q34_5             0.323    0.174    1.852    0.064    0.323    0.135
#    .Q34_7             0.837    0.248    3.371    0.001    0.837    0.340
#    .Q34_11            0.676    0.209    3.228    0.001    0.676    0.334
#    .Q34_14            0.722    0.199    3.634    0.000    0.722    0.416
#     Cognition         1.544    0.322    4.794    0.000    1.000    1.000
#     Affect            1.623    0.341    4.760    0.000    1.000    1.000
#
# R-Square:
#                    Estimate
#     Q34_1             0.602
#     Q34_4             0.642
#     Q34_5             0.865
#     Q34_7             0.660
#     Q34_11            0.666
#     Q34_14            0.584

# %%
describe(BioAttPostSubset)
# Out:
#        vars n   mean     sd       median trimmed  mad    min max range
# Q34_1  1    114 3.464912 1.608494 3      3.423913 1.4826 1   7   6
# Q34_4  2    114 3.122807 1.470298 3      3.043478 1.4826 1   7   6
# Q34_5  3    114 3.675439 1.554301 4      3.684783 1.4826 1   7   6
# Q34_7  4    114 4.473684 1.575310 4      4.532609 1.4826 1   7   6
# Q34_11 5    114 4.526316 1.427979 4      4.565217 1.4826 1   7   6
# Q34_14 6    114 4.298246 1.323242 4      4.315217 1.4826 1   7   6
#        skew        kurtosis   se
# Q34_1   0.20188767 -0.7900634 0.1506493
# Q34_4   0.31956027 -0.2989577 0.1377060
# Q34_5   0.13713984 -0.6081395 0.1455736
# Q34_7  -0.22126631 -0.4338366 0.1475413
# Q34_11 -0.29656190  0.1254903 0.1337425
# Q34_14 -0.09864958  0.2633615 0.1239330

# %%
alpha(BioAttPostSubset[c('Q34_1', 'Q34_4', 'Q34_5')])
# Out:
# Reliability analysis
# Call: alpha(x = BioAttPostSubset[c("Q34_1", "Q34_4", "Q34_5")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N  ase mean  sd median_r
#       0.88      0.88    0.83       0.7 7.1 0.02  3.4 1.4     0.71
#
#  lower alpha upper     95% confidence boundaries
# 0.84 0.88 0.92
#
#  Reliability if an item is dropped:
#       raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q34_1      0.86      0.86    0.75      0.75 6.0    0.027    NA  0.75
# Q34_4      0.83      0.83    0.71      0.71 4.8    0.032    NA  0.71
# Q34_5      0.79      0.79    0.66      0.66 3.8    0.039    NA  0.66
#
#  Item statistics
#         n raw.r std.r r.cor r.drop mean  sd
# Q34_1 114  0.88  0.88  0.77   0.73  3.5 1.6
# Q34_4 114  0.89  0.90  0.82   0.76  3.1 1.5
# Q34_5 114  0.91  0.91  0.86   0.80  3.7 1.6
#
# Non missing response frequency for each item
#          1    2    3    4    5    6    7 miss
# Q34_1 0.13 0.17 0.22 0.23 0.12 0.11 0.03    0
# Q34_4 0.18 0.12 0.32 0.23 0.08 0.05 0.02    0
# Q34_5 0.11 0.09 0.29 0.26 0.08 0.15 0.03    0

# %%
alpha(BioAttPostSubset[c('Q34_7', 'Q34_11', 'Q34_14')])
# Out:
# Reliability analysis
# Call: alpha(x = BioAttPostSubset[c("Q34_7", "Q34_11", "Q34_14")])
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean  sd median_r
#       0.84      0.84    0.78      0.63 5.2 0.026  4.4 1.3     0.61
#
#  lower alpha upper     95% confidence boundaries
# 0.79 0.84 0.89
#
#  Reliability if an item is dropped:
#        raw_alpha std.alpha G6(smc) average_r S/N alpha se var.r med.r
# Q34_7       0.76      0.76    0.61      0.61 3.1    0.046    NA  0.61
# Q34_11      0.74      0.75    0.60      0.60 3.0    0.047    NA  0.60
# Q34_14      0.81      0.82    0.69      0.69 4.5    0.034    NA  0.69
#
#  Item statistics
#          n raw.r std.r r.cor r.drop mean  sd
# Q34_7  114  0.89  0.88  0.79   0.72  4.5 1.6
# Q34_11 114  0.88  0.88  0.80   0.73  4.5 1.4
# Q34_14 114  0.83  0.85  0.71   0.66  4.3 1.3
#
# Non missing response frequency for each item
#           1    2    3    4    5    6    7 miss
# Q34_7  0.05 0.05 0.11 0.36 0.13 0.18 0.11    0
# Q34_11 0.04 0.04 0.08 0.38 0.22 0.15 0.10    0
# Q34_14 0.03 0.08 0.08 0.42 0.25 0.08 0.07    0
